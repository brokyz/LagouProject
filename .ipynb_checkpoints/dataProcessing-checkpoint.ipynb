# %%
import pandas as pd
import numpy as np
import re

# %%
fileName = ['后端开发', '移动开发', '前端开发', '人工智能', '测试', '运维', 'DBA', '硬件开发']
n = 0
creatVar = locals()
dataList = []
for i in fileName:
    path = "data/" + i + ".csv"
    creatVar["data" + str(i)] = pd.read_csv(path)
    creatVar["data" + str(i)]["tag"] = n
    dataList.append(creatVar["data" + str(i)])
    n += 1

# %%
data = pd.concat([dataList[0],dataList[1],dataList[2],dataList[3],dataList[4],dataList[5],dataList[6],dataList[7]],axis=0)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2962 entries, 0 to 299
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  2962 non-null   int64
#  1   job         2962 non-null   object
#  2   money       2962 non-null   object
#  3   skill       2954 non-null   object
#  4   ink         2722 non-null   object
#  5   area        2962 non-null   object
#  6   jobDes      2962 non-null   object
#  7   inkDes      2940 non-null   object
#  8   tag         2962 non-null   int64
# dtypes: int64(2), object(7)
# memory usage: 231.4+ KB

# %%
data.head()
# Out:
#    Unnamed: 0          job    money                         skill  \
# 0           0    Java开发工程师  15k-25k         金融业 JavaScript ORACLE
# 1           1  java高级开发工程师  13k-18k  IT技术服务｜咨询 JavaScript Eclipse
# 2           2      软件开发工程师  10k-20k   网络通信 C语言 C++ C# Linux 计算机底层
# 3           3    java开发工程师   7k-11k             IT技术服务｜咨询 软件服务｜咨询
# 4           4    java开发工程师  10k-20k                         保险 后端
#
#               ink       area                    jobDes  \
# 0    中国人寿财险金融科技中心  [上海·浦东新…]     “金融央企、六险二金、工会福利、专业通道”
# 1            届远信息   [上海·宝山区]     “五险一金，年终奖，生日福利、节日福利等”
# 2  中国兵器装备集团自动化研究所   [绵阳·游仙区]   “央企、五险一金、年休假、绩效奖金、工会福利”
# 3          广东睿盟科技    [广州·车陂]  “周末双休、带薪年假、全勤奖、餐补、五险一金等”
# 4      中华财险创新研发中心    [杭州·和睦]            “六险一金、完善的福利体制”
#
#                               inkDes  tag
# 0               金融业 / 上市公司 / 2000人以上    0
# 1  IT技术服务｜咨询,信息安全 / 不需要融资 / 150-500人    0
# 2        软件服务｜咨询 / 不需要融资 / 500-2000人    0
# 3          软件服务｜咨询 / 不需要融资 / 50-150人    0
# 4     科技金融,软件服务｜咨询 / 不需要融资 / 2000人以上    0

# %%
# file = "web前端拉勾北京.csv"
# newFile = re.findall(re.compile(r'(.*)\.csv'),file)[0] + "_预处理.csv"

# %%
# data = pd.read_csv('data/前端开发.csv')

# %%
data.isna().sum()
# Out:
# Unnamed: 0      0
# job             0
# money           0
# skill           8
# ink           240
# area            0
# jobDes          0
# inkDes         22
# tag             0
# dtype: int64

# %%
data = data.dropna()

# %%
data = data.reset_index()

# %%
data.isna().sum()
# Out:
# index         0
# Unnamed: 0    0
# job           0
# money         0
# skill         0
# ink           0
# area          0
# jobDes        0
# inkDes        0
# tag           0
# dtype: int64

# %%
# 提取最高最低薪资
# ^(\d\d?)k-(\d\d?)k
hight_wages = np.array([])
low_wages = np.array([])
for i in data['money']:
    low_wages = np.append(low_wages,int(re.findall(re.compile(r'^(\d?\d?\d?)k-(\d?\d?\d?)k'),i)[0][0]))
    hight_wages = np.append(hight_wages,int(re.findall(re.compile(r'^(\d?\d?\d?)k-(\d?\d?\d?)k'),i)[0][1]))
#     low_wages.append(int(re.findall(re.compile(r'^(\d?\d?\d?)k-(\d?\d?\d?)k'),i)[0][0]))
#     hight_wages.append(int(re.findall(re.compile(r'^(\d?\d?\d?)k-(\d?\d?\d?)k'),i)[0][1]))
year_wages = (hight_wages + low_wages) / 2 * 12

# %%
hight_wages = hight_wages.tolist()
low_wages = low_wages.tolist()
year_wages = year_wages.tolist()

# %%
# 提取城市信息
# [\u4e00-\u9fa5]+
city = []
n = 0
for i in data['area']:
    city.append(re.findall(re.compile(r'[\u4e00-\u9fa5]+'),i)[0])

# %%
len(city)
# Out:
# 2692

# %%
city
# Out:
# ['上海',
#  '上海',
#  '绵阳',
#  '广州',
#  '杭州',
#  '郑州',
#  '上海',
#  '深圳',
#  '西安',
#  '杭州',
#  '上海',
#  '杭州',
#  '广州',
#  '上海',
#  '成都',
#  '北京',
#  '广州',
#  '广州',
#  '北京',
#  '深圳',
#  '成都',
#  '北京',
#  '北京',
#  '上海',
#  '深圳',
#  '东莞',
#  '广州',
#  '上海',
#  '上海',
#  '上海',
#  '上海',
#  '东莞',
#  '上海',
#  '上海',
#  '广州',
#  '深圳',
#  '北京',
#  '深圳',
#  '杭州',
#  '广州',
#  '上海',
#  '广州',
#  '长沙',
#  '深圳',
#  '广州',
#  '长沙',
#  '深圳',
#  '深圳',
#  '唐山',
#  '深圳',
#  '北京',
#  '重庆',
#  '北京',
#  '上海',
#  '鞍山',
#  '上海',
#  '上海',
#  '北京',
#  '重庆',
#  '深圳',
#  '上海',
#  '深圳',
#  '深圳',
#  '深圳',
#  '北京',
#  '南京',
#  '苏州',
#  '北京',
#  '成都',
#  '杭州',
#  '深圳',
#  '上海',
#  '杭州',
#  '上海',
#  '沈阳',
#  '苏州',
#  '广州',
#  '深圳',
#  '成都',
#  '深圳',
#  '深圳',
#  '深圳',
#  '上海',
#  '上海',
#  '武汉',
#  '上海',
#  '上海',
#  '深圳',
#  '上海',
#  '广州',
#  '上海',
#  '深圳',
#  '上海',
#  '北京',
#  '杭州',
#  '上海',
#  '北京',
#  '深圳',
#  '杭州',
#  '北京',
#  '北京',
#  '佛山',
#  '成都',
#  '北京',
#  '杭州',
#  '苏州',
#  '深圳',
#  '深圳',
#  '苏州',
#  '深圳',
#  '武汉',
#  '上海',
#  '佛山',
#  '北京',
#  '深圳',
#  '上海',
#  '海口',
#  '北京',
#  '北京',
#  '上海',
#  '上海',
#  '杭州',
#  '北京',
#  '上海',
#  '杭州',
#  '杭州',
#  '上海',
#  '深圳',
#  '深圳',
#  '深圳',
#  '深圳',
#  '石家庄',
#  '杭州',
#  '广州',
#  '海外',
#  '深圳',
#  '深圳',
#  '上海',
#  '北京',
#  '上海',
#  '北京',
#  '北京',
#  '杭州',
#  '石家庄',
#  '杭州',
#  '上海',
#  '上海',
#  '杭州',
#  '深圳',
#  '深圳',
#  '成都',
#  '北京',
#  '北京',
#  '上海',
#  '北京',
#  '深圳',
#  '广州',
#  '杭州',
#  '杭州',
#  '深圳',
#  '深圳',
#  '沈阳',
#  '深圳',
#  '北京',
#  '深圳',
#  '深圳',
#  '青岛',
#  '海口',
#  '成都',
#  '上海',
#  '深圳',
#  '上海',
#  '广州',
#  '杭州',
#  '北京',
#  '广州',
#  '深圳',
#  '西安',
#  '上海',
#  '北京',
#  '北京',
#  '深圳',
#  '广州',
#  '杭州',
#  '深圳',
#  '北京',
#  '深圳',
#  '深圳',
#  '广州',
#  '广州',
#  '廊坊',
#  '上海',
#  '上海',
#  '北京',
#  '深圳',
#  '广州',
#  '北京',
#  '上海',
#  '深圳',
#  '深圳',
#  '贵阳',
#  '成都',
#  '深圳',
#  '北京',
#  '深圳',
#  '南京',
#  '深圳',
#  '上海',
#  '深圳',
#  '北京',
#  '南昌',
#  '深圳',
#  '广州',
#  '广州',
#  '深圳',
#  '大连',
#  '上海',
#  '北京',
#  '广州',
#  '上海',
#  '广州',
#  '大连',
#  '广州',
#  '北京',
#  '深圳',
#  '广州',
#  '杭州',
#  '北京',
#  '济南',
#  '北京',
#  '北京',
#  '上海',
#  '北京',
#  '广州',
#  '佛山',
#  '深圳',
#  '深圳',
#  '深圳',
#  '成都',
#  '广州',
#  '深圳',
#  '北京',
#  '上海',
#  '北京',
#  '上海',
#  '广州',
#  '上海',
#  '深圳',
#  '大连',
#  '深圳',
#  '郑州',
#  '成都',
#  '郑州',
#  '深圳',
#  '深圳',
#  '上海',
#  '南京',
#  '深圳',
#  '杭州',
#  '上海',
#  '西安',
#  '南京',
#  '深圳',
#  '上海',
#  '上海',
#  '上海',
#  '上海',
#  '深圳',
#  '成都',
#  '北京',
#  '深圳',
#  '深圳',
#  '杭州',
#  '深圳',
#  '北京',
#  '北京',
#  '深圳',
#  '上海',
#  '北京',
#  '深圳',
#  '北京',
#  '郑州',
#  '南京',
#  '北京',
#  '上海',
#  '上海',
#  '深圳',
#  '上海',
#  '北京',
#  '南京',
#  '佛山',
#  '上海',
#  '深圳',
#  '广州',
#  '北京',
#  '上海',
#  '北京',
#  '大连',
#  '广州',
#  '北京',
#  '北京',
#  '重庆',
#  '合肥',
#  '天津',
#  '武汉',
#  '上海',
#  '广州',
#  '佛山',
#  '北京',
#  '上海',
#  '成都',
#  '广州',
#  '上海',
#  '成都',
#  '成都',
#  '深圳',
#  '杭州',
#  '广州',
#  '成都',
#  '广州',
#  '深圳',
#  '上海',
#  '佛山',
#  '杭州',
#  '成都',
#  '成都',
#  '成都',
#  '成都',
#  '北京',
#  '深圳',
#  '上海',
#  '上海',
#  '深圳',
#  '杭州',
#  '深圳',
#  '北京',
#  '北京',
#  '南京',
#  '合肥',
#  '深圳',
#  '深圳',
#  '郑州',
#  '北京',
#  '上海',
#  '上海',
#  '上海',
#  '海口',
#  '深圳',
#  '深圳',
#  '广州',
#  '佛山',
#  '成都',
#  '深圳',
#  '北京',
#  '北京',
#  '合肥',
#  '北京',
#  '深圳',
#  '北京',
#  '广州',
#  '广州',
#  '北京',
#  '重庆',
#  '深圳',
#  '上海',
#  '北京',
#  '深圳',
#  '成都',
#  '上海',
#  '上海',
#  '深圳',
#  '北京',
#  '北京',
#  '上海',
#  '北京',
#  '成都',
#  '西安',
#  '北京',
#  '成都',
#  '北京',
#  '武汉',
#  '北京',
#  '杭州',
#  '广州',
#  '北京',
#  '杭州',
#  '深圳',
#  '成都',
#  '沈阳',
#  '上海',
#  '北京',
#  '广州',
#  '深圳',
#  '深圳',
#  '石家庄',
#  '贵阳',
#  '深圳',
#  '北京',
#  '上海',
#  '深圳',
#  '深圳',
#  '青岛',
#  '杭州',
#  '苏州',
#  '上海',
#  '宁波',
#  '成都',
#  '上海',
#  '上海',
#  '北京',
#  '广州',
#  '北京',
#  '上海',
#  '北京',
#  '宁波',
#  '武汉',
#  '福州',
#  '成都',
#  '重庆',
#  '北京',
#  '佛山',
#  '上海',
#  '武汉',
#  '上海',
#  '深圳',
#  '上海',
#  '广州',
#  '广州',
#  '上海',
#  '北京',
#  '北京',
#  '上海',
#  '上海',
#  '武汉',
#  '北京',
#  '马鞍山',
#  '杭州',
#  '深圳',
#  '北京',
#  '上海',
#  '重庆',
#  '广州',
#  '成都',
#  '上海',
#  '杭州',
#  '深圳',
#  '西安',
#  '深圳',
#  '北京',
#  '武汉',
#  '上海',
#  '深圳',
#  '东莞',
#  '北京',
#  '北京',
#  '成都',
#  '成都',
#  '广州',
#  '厦门',
#  '重庆',
#  '深圳',
#  '上海',
#  '杭州',
#  '大连',
#  '深圳',
#  '北京',
#  '上海',
#  '深圳',
#  '武汉',
#  '上海',
#  '成都',
#  '北京',
#  '广州',
#  '成都',
#  '北京',
#  '北京',
#  '北京',
#  '北京',
#  '北京',
#  '广州',
#  '杭州',
#  '北京',
#  '北京',
#  '成都',
#  '广州',
#  '北京',
#  '广州',
#  '北京',
#  '北京',
#  '深圳',
#  '北京',
#  '北京',
#  '上海',
#  '深圳',
#  '南京',
#  '深圳',
#  '广州',
#  '深圳',
#  '厦门',
#  '北京',
#  '北京',
#  '杭州',
#  '南京',
#  '北京',
#  '北京',
#  '北京',
#  '成都',
#  '北京',
#  '北京',
#  '北京',
#  '上海',
#  '广州',
#  '广州',
#  '北京',
#  '北京',
#  '西安',
#  '广州',
#  '西安',
#  '北京',
#  '武汉',
#  '广州',
#  '合肥',
#  '南京',
#  '北京',
#  '北京',
#  '北京',
#  '北京',
#  '北京',
#  '成都',
#  '成都',
#  '杭州',
#  '成都',
#  '武汉',
#  '杭州',
#  '杭州',
#  '上海',
#  '广州',
#  '西安',
#  '深圳',
#  '上海',
#  '北京',
#  '太原',
#  '赣州',
#  '广州',
#  '苏州',
#  '成都',
#  '北京',
#  '北京',
#  '北京',
#  '成都',
#  '北京',
#  '广州',
#  '合肥',
#  '北京',
#  '杭州',
#  '北京',
#  '北京',
#  '苏州',
#  '北京',
#  '上海',
#  '杭州',
#  '北京',
#  '上海',
#  '上海',
#  '杭州',
#  '北京',
#  '北京',
#  '北京',
#  '北京',
#  '上海',
#  '上海',
#  '上海',
#  '上海',
#  '杭州',
#  '杭州',
#  '北京',
#  '北京',
#  '北京',
#  '深圳',
#  '上海',
#  '北京',
#  '北京',
#  '北京',
#  '北京',
#  '北京',
#  '北京',
#  '北京',
#  '深圳',
#  '杭州',
#  '北京',
#  '上海',
#  '北京',
#  '北京',
#  '成都',
#  '成都',
#  '广州',
#  '广州',
#  '北京',
#  '北京',
#  '上海',
#  '上海',
#  '广州',
#  '广州',
#  '北京',
#  '杭州',
#  '深圳',
#  '北京',
#  '北京',
#  '广州',
#  '深圳',
#  '深圳',
#  '成都',
#  '杭州',
#  '深圳',
#  '深圳',
#  '杭州',
#  '上海',
#  '北京',
#  '北京',
#  '深圳',
#  '深圳',
#  '上海',
#  '上海',
#  '北京',
#  '上海',
#  '北京',
#  '深圳',
#  '深圳',
#  '上海',
#  '广州',
#  '青岛',
#  '深圳',
#  '深圳',
#  '成都',
#  '上海',
#  '武汉',
#  '上海',
#  '广州',
#  '西安',
#  '杭州',
#  '西安',
#  '杭州',
#  '郑州',
#  '上海',
#  '深圳',
#  '武汉',
#  '成都',
#  '成都',
#  '北京',
#  '北京',
#  '北京',
#  '成都',
#  '合肥',
#  '广州',
#  '长沙',
#  '武汉',
#  '上海',
#  '上海',
#  '重庆',
#  '上海',
#  '无锡',
#  '深圳',
#  '广州',
#  '上海',
#  '东莞',
#  '南京',
#  '上海',
#  '上海',
#  '北京',
#  '南宁',
#  '石家庄',
#  '北京',
#  '重庆',
#  '南京',
#  '上海',
#  '广州',
#  '苏州',
#  '成都',
#  '深圳',
#  '上海',
#  '郑州',
#  '上海',
#  '北京',
#  '北京',
#  '深圳',
#  '深圳',
#  '广州',
#  '上海',
#  '成都',
#  '西安',
#  '武汉',
#  '武汉',
#  '深圳',
#  '上海',
#  '深圳',
#  '长沙',
#  '上海',
#  '北京',
#  '上海',
#  '成都',
#  '上海',
#  '成都',
#  '北京',
#  '北京',
#  '北京',
#  '上海',
#  '北京',
#  '北京',
#  '成都',
#  '成都',
#  '深圳',
#  '深圳',
#  '成都',
#  '深圳',
#  '广州',
#  '上海',
#  '成都',
#  '成都',
#  '成都',
#  '上海',
#  '武汉',
#  '深圳',
#  '上海',
#  '上海',
#  '杭州',
#  '深圳',
#  '武汉',
#  '杭州',
#  '深圳',
#  '武汉',
#  '深圳',
#  '杭州',
#  '上海',
#  '南京',
#  '上海',
#  '深圳',
#  '北京',
#  '南昌',
#  '合肥',
#  '北京',
#  '上海',
#  '深圳',
#  '北京',
#  '成都',
#  '深圳',
#  '广州',
#  '深圳',
#  '上海',
#  '成都',
#  '杭州',
#  '北京',
#  '深圳',
#  '北京',
#  '重庆',
#  '上海',
#  '广州',
#  '西安',
#  '上海',
#  '杭州',
#  '北京',
#  '上海',
#  '武汉',
#  '武汉',
#  '珠海',
#  '北京',
#  '杭州',
#  '上海',
#  '上海',
#  '大连',
#  '北京',
#  '北京',
#  '嘉兴',
#  '南京',
#  '上海',
#  '杭州',
#  '北京',
#  '深圳',
#  '北京',
#  '深圳',
#  '广州',
#  '北京',
#  '杭州',
#  '深圳',
#  '武汉',
#  '武汉',
#  '杭州',
#  '深圳',
#  '北京',
#  '北京',
#  '上海',
#  '上海',
#  '上海',
#  '深圳',
#  '北京',
#  '上海',
#  '广州',
#  '深圳',
#  '杭州',
#  '深圳',
#  '上海',
#  '上海',
#  '北京',
#  '上海',
#  '上海',
#  '广州',
#  '深圳',
#  '杭州',
#  '北京',
#  '深圳',
#  '北京',
#  '上海',
#  '上海',
#  '上海',
#  '哈尔滨',
#  '武汉',
#  '上海',
#  '深圳',
#  '深圳',
#  '广州',
#  '北京',
#  '北京',
#  '长沙',
#  '海口',
#  '上海',
#  '上海',
#  '上海',
#  '广州',
#  '深圳',
#  '北京',
#  '杭州',
#  '深圳',
#  '上海',
#  '成都',
#  '北京',
#  '上海',
#  '上海',
#  '上海',
#  '广州',
#  '武汉',
#  '东莞',
#  '深圳',
#  '杭州',
#  '深圳',
#  '苏州',
#  '广州',
#  '上海',
#  '成都',
#  '嘉兴',
#  '杭州',
#  '上海',
#  '深圳',
#  '成都',
#  '上海',
#  '上海',
#  '长沙',
#  '武汉',
#  '北京',
#  '北京',
#  '上海',
#  '深圳',
#  '北京',
#  '上海',
#  '郑州',
#  '杭州',
#  '深圳',
#  '上海',
#  '北京',
#  '成都',
#  '广州',
#  '惠州',
#  '佛山',
#  '北京',
#  '北京',
#  '杭州',
#  '北京',
#  '上海',
#  '上海',
#  '上海',
#  '深圳',
#  '北京',
#  '北京',
#  '杭州',
#  '金华',
#  '深圳',
#  '上海',
#  '深圳',
#  '武汉',
#  '上海',
#  '上海',
#  '南京',
#  '上海',
#  '北京',
#  '上海',
#  '广州',
#  '苏州',
#  '成都',
#  '上海',
#  '广州',
#  '深圳',
#  '北京',
#  '北京',
#  '成都',
#  '深圳',
#  '杭州',
#  '上海',
#  '上海',
#  '深圳',
#  '上海',
#  '北京',
#  '北京',
#  '北京',
#  '上海',
#  '上海',
#  '杭州',
#  '成都',
#  '北京',
#  '广州',
#  '北京',
#  '北京',
#  '长沙',
#  '上海',
#  '成都',
#  '深圳',
#  '北京',
#  '上海',
#  '广州',
#  '广州',
#  '深圳',
#  '上海',
#  '成都',
#  '上海',
#  '北京',
#  '武汉',
#  '广州',
#  '上海',
#  '北京',
#  '深圳',
#  '深圳',
#  '深圳',
#  '上海',
#  '广州',
#  '西安',
#  '武汉',
#  '广州',
#  '广州',
#  '深圳',
#  '上海',
#  '成都',
#  '广州',
#  '太原',
#  '北京',
#  '杭州',
#  '郑州',
#  '长沙',
#  '武汉',
#  '广州',
#  '深圳',
#  '深圳',
#  '北京',
#  '北京',
#  '南京',
#  '杭州',
#  '上海',
#  '杭州',
#  '上海',
#  '上海',
#  '成都',
#  '北京',
#  '北京',
#  '广州',
#  '杭州',
#  '深圳',
#  '上海',
#  '杭州',
#  '深圳',
#  '广州',
#  '武汉',
#  '深圳',
#  '北京',
#  '上海',
#  '北京',
#  '上海',
#  '深圳',
#  '杭州',
#  '上海',
#  '武汉',
#  '上海',
#  '绵阳',
#  '杭州',
#  '上海',
#  '南京',
#  '深圳',
#  '北京',
#  '上海',
#  '杭州',
#  '深圳',
#  '武汉',
#  '上海',
#  '北京',
#  '上海',
#  ...]

# %%
# [a-zA-Z]+
skill = []
for i in data['skill']:
    skill.append(",".join(re.findall(re.compile(r'[a-zA-Z]+'),i)))

# %%
skill
# Out:
# ['JavaScript,ORACLE',
#  'IT,JavaScript,Eclipse',
#  'C,C,C,Linux',
#  'IT',
#  '',
#  'SQL,Linux,Unix',
#  'Hibernate,MyBatis,Spring',
#  'MySQL,ORACLE,Linux',
#  '',
#  '',
#  'IT',
#  'IT',
#  'Spring,MySQL,ORACLE',
#  'IT,Spring,MyBatis,Tomcat',
#  'Spring,MyBatis,MySQL,PostgreSQL,PSQL',
#  'Spring,MySQL',
#  'Python,Golang',
#  'PostgreSQL,PSQL,GO,Python',
#  '',
#  'IT,C,PHP,Python',
#  'JAVA,PHP,Ruby,NET,Node,js',
#  'JAVA,Python,Linux,SaaS',
#  '',
#  '',
#  'IT,C,PHP,JavaScript,CSS,MySQL',
#  'JavaScript,Web,iOS',
#  'IT,C,JavaScript,Html,TypeScript',
#  'IT,JavaScript,Spring',
#  '',
#  'IT,Spring,Hibernate,MyBatis,ORACLE',
#  'IT,Spring,MyBatis,MySQL,ORACLE',
#  'JavaScript,Web,iOS',
#  'IT,JavaScript,Spring',
#  '',
#  'JavaScript,Spring,MyBatis,Eclipse',
#  'Spring',
#  'app',
#  '',
#  'JavaScript,Node,js',
#  '',
#  'GO',
#  'IT,CSS,ORACLE',
#  'IT,Vue,Spring',
#  'IT,JavaScript,MyBatis,SQL,Server',
#  'IT,CSS,ORACLE',
#  'IT,Vue,Spring',
#  '',
#  'Vue,MySQL,springboot',
#  'Spring,Linux,ES,Hive',
#  'Spring',
#  'Spring,MyBatis,IDEA',
#  'MySQL,ORACLE',
#  'app',
#  '',
#  '',
#  'Socket,Spring,MyBatis',
#  'IT,Vue,Spring,MyBatis,ORACLE',
#  'IT,SQL,Spring,MyBatis,MySQL',
#  'Python,Spring,ORACLE',
#  'Spring',
#  'Spring',
#  'ORACLE,Spring',
#  'IT,JavaScript,MyBatis,SQL,Server',
#  'JavaScript,MyBatis',
#  'IT,MySQL,Linux',
#  'IT,Javaboot,Javacloud',
#  'IT,C,C',
#  'app',
#  'Springcloud,Springboot,redis',
#  'MyBatis,Spring',
#  'Vue,MySQL,springboot',
#  'IT',
#  'JavaScript,Node,js',
#  'Spring',
#  '',
#  'IT,C,C',
#  '',
#  '',
#  'Springcloud,Springboot,redis',
#  '',
#  '',
#  'ORACLE,Spring',
#  'IT,JavaScript,Spring',
#  'GO',
#  'Spring,MySQL',
#  'IT,Vue,Spring,MyBatis,ORACLE',
#  '',
#  '',
#  'PostgreSQL,PSQL,Linux',
#  'JavaScript,Spring,MyBatis,IT',
#  'PostgreSQL,PSQL,Linux',
#  '',
#  'React,Vue',
#  'GO,Python,MyBatis,SQL,Server',
#  'Spring,MyBatis,ORACLE',
#  'IT,C,GO',
#  'IT,MyBatis,Spring',
#  'JavaScript,MyBatis',
#  '',
#  'JAVA',
#  'IT,Netty,MySQL,Linux,TCP,IP',
#  'IT,Spring,MySQL',
#  '',
#  'IT,Vue',
#  'JavaScript,Node,js',
#  'IT,C,C',
#  'Spring,MySQL',
#  '',
#  'IT,JAVA,C,C,Java,NET,C',
#  'Spring',
#  'Spring',
#  '',
#  'IT,Spring,MySQL',
#  'IT,Spring,MyBatis,MySQL',
#  'IT,Spring,SQL,Server,MySQL',
#  '',
#  'JAVA,C,Python,C',
#  'Spring,MyBatis,MySQL',
#  'JAVA,node',
#  '',
#  'IT',
#  '',
#  'MySQL,IDEA',
#  'Socket,Spring,MyBatis',
#  'SQL',
#  '',
#  'IT,Vue,Spring,MyBatis,ORACLE',
#  'Netty,TCP,IP,SpringBoot,K,S',
#  'IT,Python,MySQL,ORACLE,Linux',
#  '',
#  'IT,Spring,Tomcat',
#  'IT',
#  'Spring,MyBatis,ORACLE',
#  'JavaScript,Spring,MyBatis,IT',
#  'JAVA,Python,GO,MySQL,Linux',
#  'JavaScript,Spring,MySQL',
#  '',
#  'Spring,MySQL,Web,Tomcat',
#  'IT,MySQL,ORACLE,JDK,SpringMvc',
#  '',
#  'Spring,MyBatis,MySQL',
#  'IT,MyBatis,Spring',
#  'IT',
#  'IT',
#  'Spring,MyBatis,ORACLE',
#  'IT,C,GO',
#  'IT,MySQL,ORACLE,Elastic,Search',
#  '',
#  'JavaScript,Spring,MySQL',
#  'JAVA,PL,SQL,Spring',
#  'MyBatis,MySQL,Web',
#  '',
#  '',
#  'IT',
#  'C,JAVA,Python,Golang',
#  'PHP',
#  'Spring',
#  'IT',
#  'IT,JavaScript,Spring,MyBatis,ORACLE',
#  '',
#  'Spring,MySQL',
#  '',
#  'IT,Spring,SQL,Server,MySQL',
#  'IT,JavaScript,CSS,XML,Eclipse',
#  '',
#  'IT',
#  '',
#  'JAVA,C,Python,C',
#  'ORACLE',
#  'Spring,MySQL,Web,Tomcat',
#  '',
#  '',
#  '',
#  'IT,JavaScript,Spring,MyBatis,ORACLE',
#  'MySQL,IDEA',
#  'Spring',
#  'Spring',
#  'Spring,SQL,Server',
#  'IT',
#  'Spring,MyBatis,MySQL',
#  'IT,Spring,MyBatis,MySQL',
#  'Spring',
#  'JavaScript,Spring,MyBatis,IT',
#  '',
#  'Flutter,Spring,Web',
#  'Hadoop',
#  'JavaScript,Spring,MySQL',
#  '',
#  'Spring,MyBatis,ORACLE',
#  '',
#  'Linux',
#  '',
#  'Spring,SQL,Server,ORACLE',
#  'JavaScript,Hibernate,MyBatis,springboot,Docker',
#  '',
#  '',
#  'IT,JavaScript,CSS,XML,Eclipse',
#  'Spring,MyBatis,Linux,MySQL',
#  'IT',
#  'JAVA,Python,Node,js,Java',
#  '',
#  'ORACLE',
#  '',
#  'MyBatis,MySQL,PostgreSQL,PSQL',
#  'IT,Spring,MyBatis,MySQL',
#  'Linux',
#  'C,VC,Windows,Linux',
#  'IT',
#  'Spring',
#  'IT,Spring,MyBatis,MySQL',
#  '',
#  'Spring,MySQL',
#  '',
#  '',
#  'IT,Spring,SQL,Server,MySQL',
#  'JAVA,C,Python',
#  'IT,MySQL,ORACLE,Elastic,Search',
#  'SQL,Spring,ORACLE,Linux',
#  '',
#  'MyBatis,Tomcat',
#  'JavaScript,MySQL',
#  'JavaScript,MyBatis',
#  'MyBatis,Windows',
#  'JavaScript,Hibernate,MyBatis,springboot,Docker',
#  '',
#  '',
#  '',
#  'MyBatis,Hadoop,ORACLE',
#  'Linux',
#  'IT,MyBatis,MySQL,ORACLE',
#  'IT,JavaScript,CSS,XML,Eclipse',
#  '',
#  'JAVA,Spring,PostgreSQL,PSQL,Linux,SaaS',
#  'JavaScript,Spring,MyBatis,IT',
#  '',
#  'IT',
#  'JavaScript,Spring,MySQL',
#  'Spring',
#  'IT',
#  'Spring,MyBatis,ORACLE',
#  'Spring,SQL,Server,Linux',
#  'MyBatis,Python,MySQL',
#  'Spring,MyBatis',
#  '',
#  '',
#  'Spring,Tomcat,SQL,Server,Linux',
#  'Spring,SQL,Server,ORACLE',
#  '',
#  'JAVA,C,Python',
#  'Spring',
#  'IT,SQL,Server,MyBatis',
#  'Spring,MySQL,Linux,Kafka,TOMCAT',
#  'IT,Spring,MyBatis,MySQL',
#  '',
#  'TypeScript,Spring,MySQL,Linux',
#  'JAVA',
#  'Python,GO,MySQL',
#  '',
#  'Python,Django,Linux',
#  'Spring,MyBatis,Linux,MySQL',
#  'Python,HTML,Html,SQL',
#  'Linux',
#  'Flutter,Spring,Web',
#  'MyBatis,Tomcat',
#  'Spring,MyBatis,SQL,Server',
#  'IT,JAVA,PHP,Python,NET,Node,js',
#  '',
#  '',
#  'Spring,Struts,Hibernate,MyBatis',
#  'JAVA',
#  'Spring',
#  '',
#  '',
#  'IT,Spring,MyBatis,MySQL',
#  'C,GO',
#  'GO,Python,C',
#  'Spring,MySQL',
#  'Spring,MyBatis',
#  'JAVA,Node,js,Linux,Web',
#  '',
#  'MyBatis,MySQL,PostgreSQL,PSQL',
#  '',
#  'Python,SQL,Linux',
#  'Python,Django,Hadoop,Flask,PostgreSQL,PSQL',
#  'IT,TCP,IP',
#  'Memcache,MySQL',
#  'IT,SQL,MySQL',
#  '',
#  'C,GO',
#  'IT',
#  '',
#  '',
#  'IT',
#  '',
#  '',
#  '',
#  'Python,Django,Hadoop,Flask,PostgreSQL,PSQL',
#  'JAVA,C,Python',
#  '',
#  'IT,JAVA,IDEA,MySQL,ORACLE,DB',
#  'SQL,Spring,MyBatis',
#  'IT,Spring,MyBatis,MySQL',
#  'IT,Spring,MyBatis',
#  'IT,Spring,Linux',
#  'IT,Spring,MyBatis,MySQL',
#  '',
#  '',
#  'IT,Spring,MySQL',
#  'IT,Spring,SQL,Server,TCP,IP',
#  'Spring,Struts,Hibernate,MyBatis',
#  'JAVA,C,Python,GO,Linux',
#  'Spring,Struts,Hibernate,SQL,Server',
#  'Spring,MyBatis',
#  'IT',
#  '',
#  'Spring,MySQL',
#  'C,Python,JAVA,TCP,IP',
#  'IT',
#  'Spring,Linux,MySQL',
#  'IT,JAVA',
#  '',
#  'Spring,MyBatis',
#  'JAVA,C,GO',
#  'JavaScript,Node,js',
#  'IT,Spring,Linux,postgreSQL',
#  'JavaScript,Node,js,MongoDb,Redis',
#  'IT,MyBatis,Springboot,Springmvc',
#  'Hibernate,MyBatis',
#  'IT,Node,js,MySQL',
#  '',
#  '',
#  'IT,Spring,MySQL,Elastic,Search,activity',
#  'IT,Spring',
#  '',
#  '',
#  'Hibernate,ORACLE',
#  'MySQL,ORACLE',
#  'IT,SQL,Spring,ORACLE',
#  '',
#  'IT',
#  'IT,MyBatis,Tomcat,ORACLE',
#  '',
#  'JavaScript,MyBatis',
#  'Spring',
#  'IT',
#  'IT,TCP,IP',
#  'JAVA,C,Python,C',
#  'SQL,Server,MyBatis',
#  'C',
#  '',
#  'IT',
#  '',
#  '',
#  'Spring,MyBatis,ORACLE',
#  'IT,JavaScript,SQL,Server,ORACLE',
#  '',
#  '',
#  'JavaScript,Web',
#  '',
#  'Linux',
#  '',
#  'Spring',
#  'JAVA',
#  '',
#  'IT,JAVA,Vue,Spring,SQL,Server',
#  'IT,Spring,Linux',
#  'Spring,SQL,Server,Kafka,kubernetes',
#  'C,PHP,Perl,Ruby,Node,js',
#  'JAVA,Hadoop,Spring,elasticsearch,Kafka',
#  'Spring,MySQL,Linux',
#  'JavaScript,Spring,MyBatis',
#  'IT,MySQL,ORACLE,JDK,SpringMvc',
#  'C',
#  'JAVA,C,Python,Spring,TCP,IP',
#  '',
#  'Spring,JAVA',
#  'IT,Spring,MyBatis,MySQL,ORACLE',
#  'IT,MyBatis,Spring',
#  'Spring,JAVA',
#  'IT,MyBatis,IDEA',
#  'NET,Netty,MySQL',
#  'Spring,Linux',
#  '',
#  'Spring,MyBatis,MySQL,ORACLE',
#  '',
#  '',
#  'IT',
#  '',
#  '',
#  'Hadoop,Elastic,Search',
#  'Spring,MyBatis,MySQL',
#  '',
#  'IT,JAVA',
#  '',
#  'Spring,MyBatis,MySQL',
#  'IT,JAVA,JavaScript,SQL',
#  'Python,TypeScript,Node,js',
#  'PHP,Memcache,MySQL,Linux',
#  'JAVA,Spring,MySQL,Lucene,Elastic,Search',
#  'C,Python,NET',
#  '',
#  '',
#  'Spring,MySQL,Linux',
#  'JavaScript,MyBatis,Android',
#  'JAVA,Python,GO',
#  'IT',
#  'Spring,MySQL,ORACLE,SQL,Server',
#  'IT,JavaScript,HTML,Spring,MyBatis',
#  '',
#  'C,React,Vue,SQL,Server',
#  '',
#  'Shell',
#  'Spring,SQL,Server,MySQL',
#  'Linux,Shell,JAVA',
#  '',
#  '',
#  'Spring,MySQL',
#  'IT,JAVA',
#  'IT,Vue,Web,Web,MySQL',
#  'Spring,MySQL,ORACLE',
#  'IT,Spring,MySQL,ORACLE',
#  '',
#  'HTML,MySQL',
#  'IT,Spring,MySQL',
#  '',
#  '',
#  'Spring',
#  'IT',
#  'Spring,SpringCloud',
#  '',
#  '',
#  'Python,Html,Node,js,Java',
#  'IT,Spring,Hibernate,MyBatis',
#  'Hibernate,MyBatis,SQL,Server',
#  'JavaScript,MyBatis,ORACLE,MySQL',
#  '',
#  'Android,iOS',
#  'Android,COCOS,D,X',
#  'Swift',
#  '',
#  'JAVA,Kotlin',
#  'PHP,Vue,Linux,SQL,Server',
#  'IT,JAVA',
#  'IT,JAVA',
#  'JAVA',
#  'iOS,Android',
#  'CSS,Android,iOS,JavaScript,HTML',
#  'IT,TCP,IP',
#  'Objective,C,Flutter,iOS,Swift',
#  'Android,iOS',
#  '',
#  '',
#  'iOS,Html,Netty,Objective,C',
#  '',
#  'Android,iOS,SDK,Demo',
#  'IT,Spring,MyBatis,Android',
#  'Android',
#  'Android,iOS,Swift,Kotlin',
#  'JavaScript',
#  'Html,Unix',
#  'IT,JAVA,JavaScript,Objective,C',
#  'Objective,C,JAVA',
#  'JAVA,Swift,Kotlin,Android,iOS',
#  'JAVA,Angular',
#  'C',
#  'JavaScript,Html,Vue',
#  'Objective,C',
#  '',
#  'Android,JAVA',
#  'JavaScript,Android,React',
#  'C',
#  '',
#  'IT,Redux,Web',
#  '',
#  '',
#  'React,iOS,Android',
#  'IT,Spring',
#  '',
#  'IT,Android,React,JAVA',
#  'HTML,Angular',
#  'IT,C,JAVA',
#  'DirectX,OpenGL,vulkan',
#  'Objective,C,TCP,IP',
#  'IT,JAVA,Kotlin',
#  'MCN,JavaScript,HTML,Javascript,Node,js',
#  'React',
#  'MCN,CSS,JAVA,Html',
#  'C',
#  'JAVA,Kotlin',
#  'Swift',
#  '',
#  '',
#  'JAVA,Objective,C,Swift',
#  'Objective,C,C',
#  'MyBatis,Spring,MySQL',
#  'Objective,C,Swift',
#  '',
#  'Objective,C,Swift,Socket,Autolayout',
#  'Android',
#  'C,Objective,C,Swift',
#  'XML,OC,Swift',
#  '',
#  '',
#  '',
#  'JavaScript,React,HTML,Vue,Web',
#  'Kotlin,JAVA',
#  'JAVA,Objective,C',
#  'VR,SDK',
#  'Swift,OC',
#  'JavaScript,Socket,MySQL',
#  '',
#  'IT,Html,JavaScript',
#  'IT,Html,JavaScript',
#  '',
#  '',
#  'JAVA',
#  'JAVA,Android',
#  'Kotlin',
#  'Html,Node,js,Angular,Vue',
#  'JAVA,Html,Vue',
#  'Python',
#  'IT,JAVA',
#  '',
#  '',
#  'IT,JavaScript,Flutter,Android',
#  'IT,JavaScript,Flutter',
#  'Unity,D',
#  'Objective,C,JAVA,C,Swift',
#  'Objective,C,Swift',
#  'JAVA,Kotlin',
#  '',
#  'JAVA,PHP,Python,MySQL,Linux',
#  'IT',
#  'JavaScript,Html,React,Vue,Android',
#  'JavaScript,Html,React,Vue,Android',
#  'JAVA,MySQL',
#  'IT',
#  '',
#  'AndroidStudio',
#  'Objective,C,Swift',
#  '',
#  '',
#  'JavaScript',
#  'IT,Swift',
#  '',
#  'IT,JAVA,TypeScript,JavaScript,React,Vue',
#  '',
#  'Swift',
#  '',
#  'IT',
#  '',
#  'JAVA',
#  '',
#  '',
#  '',
#  '',
#  'IT,JAVA,JavaScript,Android',
#  'Objective,C,Swift',
#  'Socket,JAVA',
#  '',
#  'MCN,JAVA',
#  '',
#  'IT,Python,Angular,Spring,MyBatis',
#  'IT,Swift',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'JAVA,Kotlin',
#  'JAVA,Kotlin',
#  'Objective,C',
#  '',
#  '',
#  'C',
#  'Objective,C,Swift',
#  'Objective,C,Swift',
#  'Objective,C,Swift',
#  'JAVA',
#  'Objective,C',
#  '',
#  'C,C,iOS,Android',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'JAVA',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Swift',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Objective,C,Swift',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'JAVA,Kotlin,Flutter',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'JavaScript,Angular,Android',
#  'C,Windows,Mac,OS,X,react',
#  'HTML,CSS',
#  'IT,JavaScript,Html',
#  'IT,Vue',
#  'IT',
#  'IT',
#  'JavaScript,Html',
#  '',
#  '',
#  'IT,JavaScript,HTML,ES',
#  'IT,HTML,Html,CSS,JavaScript,Vue',
#  'JavaScript,HTML,jQuery',
#  'JavaScript,React,Web,TypeScript',
#  'JavaScript,Angular,Vue,CSS',
#  'IT,HTML,CSS,Vue,Uni,app',
#  'IT,HTML,CSS,JavaScript,Vue',
#  'JavaScript,Node,js,Android,Vue,React',
#  '',
#  'JavaScript,Vue',
#  'JavaScript,TypeScript',
#  'Vue',
#  'JavaScript,Html',
#  'IT,HTML,PHP,Html',
#  'IT,JavaScript,Spring,SQL,Server,MySQL',
#  'HTML,CSS,React,Vue',
#  'React',
#  'Html,React,HTML,Javascript,CSS',
#  'CSS,JavaScript',
#  'Vue',
#  'IT,JavaScript,Angular,Javascript',
#  'IT,HTML,CSS,TCP,IP,Node,js',
#  'IT,JavaScript,TypeScript,Vue,webGL',
#  'IT,Vue,Html,CSS,JavaScript',
#  'IT,Vue,Linux,HTML,JS',
#  'React,Redux',
#  'JavaScript,TypeScript,Angular,HTML,Javascript,CSS',
#  'IT,JavaScript,Html,CSS,Vue',
#  '',
#  'IT,JavaScript,Html,CSS,Vue',
#  'Vue',
#  'IT,Vue',
#  'IT,Html,React,Javascript',
#  'React',
#  'JavaScript,React,native,HTML,HTML',
#  'JavaScript,Html',
#  'JavaScript,Angular,Node,js,HTML',
#  'Vue,jquery,xhtml,xml',
#  'IT,JavaScript,TypeScript,Vue,webGL',
#  'IT,JavaScript,Html,CSS,Vue',
#  'IT',
#  'JavaScript,TypeScript,Vue',
#  'IT,JavaScript,CSS,Vue,HTML',
#  'IT,Html,CSS,JavaScript,Vue',
#  'IT,JavaScript,Angular,Javascript',
#  'IT,HTML,CSS,TCP,IP,Node,js',
#  'React,Redux',
#  'JavaScript,Angular,Node,js',
#  'HTML,Html,CSS,Vue',
#  '',
#  '',
#  'JavaScript,TypeScript,Html,React,Vue',
#  'IT,JavaScript,Html',
#  '',
#  'HTML,Vue',
#  'React',
#  'JavaScript,Html,CSS',
#  'JavaScript,HTML,React,Vue',
#  'IT,JavaScript,Html',
#  'JavaScript,Node,js',
#  'JavaScript,HTML,CSS,Vue',
#  'IT',
#  'JavaScript,Angular,Vue,React,HTML',
#  'JavaScript,React,SaaS',
#  'IT,JavaScript,CSS,Vue',
#  'React,Redux,React,native,Javascript',
#  'Vue',
#  'IT,HTML,Html,CSS',
#  'IT,Vue',
#  'JavaScript,Node,js,Vue,HTML,CSS',
#  '',
#  'JavaScript,Html,CSS,Vue',
#  'IT,JavaScript,Angular,Javascript',
#  'IT,HTML,CSS,TCP,IP,Node,js',
#  'React,Redux',
#  'JavaScript,Angular,Node,js',
#  'IT,JavaScript,Html,CSS,Vue',
#  'JavaScript,TypeScript,Angular',
#  'Html,Angular',
#  'IT',
#  'IT,JavaScript,HTML,React,Vue',
#  'JavaScript,CSS,React,Vue',
#  'JavaScript,Html,CSS,React,Vue',
#  'Vue',
#  'JavaScript,React,Vue',
#  '',
#  'IT,JavaScript,CSS,Vue',
#  'JavaScript,Html,CSS,Vue,Node,js',
#  'JavaScript,NET,Vue,React,CSS',
#  'IT,Html,CSS,JavaScript,Vue',
#  'HTML,JavaScript,React,Vue',
#  'IT,JavaScript,Html',
#  'IT,TypeScript,Vue,Node,js',
#  'React',
#  'IT,HTML,CSS,Vue,MyBatis',
#  'TypeScript,HTML,CSS,Node,js',
#  'IT,JAVA',
#  'Vue',
#  '',
#  'MCN,TypeScript,Angular,MVC',
#  'HTML,CSS,Vue,Web',
#  'Vue',
#  'JavaScript,Vue,Angular,React,HTML',
#  'IT,JavaScript,Angular,Javascript',
#  'IT,HTML,CSS,TCP,IP,Node,js',
#  'IT,JavaScript',
#  'React,Redux',
#  'JavaScript,Angular,Node,js,Vue',
#  'HTML,JavaScript,React,Vue',
#  'React,Vue,Angular',
#  'IT,Html,CSS,JavaScript,Vue',
#  'JavaScript,HTML,CSS',
#  'JavaScript,HTML,CSS',
#  '',
#  'TypeScript,Vue,Node,js',
#  'IT,Vue,React,Angular',
#  'HTML,CSS,HTML,Javascript,Node,js',
#  'Vue',
#  'JavaScript,Html,React,Vue',
#  'JavaScript,Html,React,Node,js',
#  'IT,JavaScript,Html',
#  '',
#  'IT,JavaScript,React,Vue',
#  'IT,Vue,React',
#  'Vue',
#  'React',
#  'IT,JavaScript,Html,Vue',
#  'Html,JavaScript,CSS',
#  'IT,JavaScript,Vue',
#  'CSS,HTML,Html,React,Vue',
#  'JavaScript,React,Vue',
#  'JavaScript,HTML,Vue,Angular',
#  'Vue',
#  'Vue,JavaScript,Html,HTML',
#  'Vue',
#  'IT,Html,CSS,JavaScript,Vue',
#  'JavaScript,Html',
#  'IT,JavaScript,Angular,Javascript',
#  'IT,HTML,CSS,TCP,IP,Node,js',
#  'Vue',
#  'Vue',
#  'JavaScript,Html,CSS,MySQL',
#  'IT,JavaScript,Html',
#  '',
#  'Vue',
#  'JavaScript,Html',
#  'JavaScript,Angular,Html',
#  'CSS,JavaScript,HTML,Html',
#  'IT,JavaScript,Html,Vue',
#  'JavaScript,SQL,Server',
#  'JavaScript,TypeScript,Angular',
#  'C,JavaScript,HTML,Html,Flutter',
#  'JavaScript,Html,React,Vue',
#  'JavaScript,Html',
#  'IT,HTML,CSS,TCP,IP,Node,js',
#  'JavaScript,HTML,CSS,Vue',
#  'IT,JavaScript,Web,HTML,ES',
#  'JavaScript,Html,Vue',
#  'JavaScript,TypeScript',
#  '',
#  'IT,HTML,Html,Vue,Node,js',
#  'C,NET,Spring',
#  'JavaScript,Web,React,HTML',
#  'IT,JavaScript,HTML,CSS',
#  'IT,JavaScript,HTML,Html,React,Vue',
#  'React,Vue,Web',
#  'JavaScript,TypeScript,Angular,React,Vue',
#  'JavaScript,Html',
#  'JavaScript,Angular',
#  'JavaScript,HTML,CSS,React,Vue',
#  'TypeScript,JavaScript',
#  'IT,JavaScript,Html,Vue',
#  'IT,Web',
#  'HTML,Vue,Web',
#  'JavaScript,PHP,Python,TypeScript,React',
#  'TypeScript,React',
#  'JavaScript,Html',
#  'IT,JavaScript,Vue',
#  'TypeScript,JavaScript,Node,js,Html',
#  'JavaScript,Angular,HTML,CSS',
#  'JavaScript,Angular,Web,HTML,Angularjs',
#  '',
#  'HTML,Html,Linux',
#  'Angular,React',
#  'JavaScript,Html',
#  'IT,HTML,CSS,TCP,IP,Node,js',
#  'JavaScript,HTML,CSS,Vue',
#  'IT,HTML,CSS,JavaScript,Web',
#  'IT,JavaScript,Web,HTML,ES',
#  'JavaScript,Angular,Android',
#  'JavaScript,TypeScript',
#  'JavaScript,TypeScript,HTML,Html,Flutter',
#  'JavaScript,Vue,Angular,Web,Windows',
#  '',
#  'C,NET,Spring',
#  'IT,React,Vue,Angular',
#  'IT,JavaScript,HTML,CSS',
#  'IT,JavaScript,Html',
#  'Html,JavaScript,CSS',
#  'IT,JavaScript,Vue,HTML',
#  'IT,JavaScript,React,Redux,SQL,Server',
#  'JavaScript,Html',
#  'JavaScript,React,Vue,uni,app',
#  'Html,Angular',
#  'IT,JavaScript,Html,Vue',
#  'Vue,React',
#  'JavaScript,Objective,C,Vue',
#  'JavaScript,Html,HTML',
#  'Vue',
#  'IT,JavaScript,HTML,CSS,Spring',
#  'JavaScript,HTML,CSS,VUE,react',
#  'TypeScript,HTML,React,Vue,Node',
#  'JAVA,HTML,Html,CSS',
#  'JavaScript,Angular,Web,HTML,Angularjs',
#  'Angular,React',
#  'React,Vue,Angular',
#  'JavaScript,HTML,Vue',
#  'JavaScript,Html',
#  'JavaScript,HTML,CSS,Vue',
#  '',
#  '',
#  'Vue,Spring',
#  'IT,JavaScript,Web,HTML,ES',
#  'JavaScript,Angular,Android',
#  'JavaScript,TypeScript',
#  'React',
#  'JAVA,React,Redux',
#  'IT,JavaScript,HTML,CSS',
#  'IT,TypeScript,JavaScript,CSS,HTML,vue',
#  '',
#  'JavaScript,CSS,Python',
#  'IT,React,Vue',
#  'JAVA,C,PHP,Node,js',
#  'React,Vue,Angular',
#  '',
#  'Vue',
#  'IT,JavaScript,Html',
#  'IT,JavaScript,HTML,CSS,three,js,webgl',
#  'IT',
#  'IT,Html,CSS,React,Vue',
#  'TypeScript,JavaScript',
#  'Vue,MySQL',
#  'IT,JavaScript,Vue,HTML',
#  'JavaScript,CSS',
#  'JavaScript,Html',
#  'IT,React,Vue,Angular',
#  'JavaScript,HTML,CSS,Vue,Node,js',
#  'Html,Vue',
#  'Vue',
#  'IT,JavaScript,Html,Vue',
#  'IT,JavaScript,HTML,SQL,Vue,Node,js',
#  'JavaScript,Html',
#  'JavaScript,Html,CSS,Vue',
#  'Vue,Echarts,Element',
#  'HTML,CSS,Angular',
#  '',
#  'Vue,Angular',
#  'IT,React',
#  'JavaScript,HTML,Vue',
#  'IT,JavaScript,Html,Vue',
#  'IT,Web',
#  'React',
#  'CSS,Vue,Spring,MySQL',
#  'JavaScript,Html',
#  '',
#  'JavaScript,HTML,CSS,Vue',
#  'JavaScript,Html,HTML',
#  'JavaScript,Android,HTML',
#  'HTML,CSS,React,Vue,SaaS',
#  'Vue,HTML,webpack',
#  'IT',
#  'JavaScript,TypeScript',
#  'JavaScript,React',
#  'IT,CSS,Html,Vue,SQL,Server,ORACLE',
#  'IT,Vue',
#  'IT,JavaScript,HTML,CSS',
#  'IT,JavaScript,Spring,SQL,Server,MySQL',
#  'JavaScript,Html,CSS,React',
#  'Html,JavaScript,Vue',
#  '',
#  'React,Web,HTML,CSS,JavaScript',
#  'JavaScript,HTML,Javascript,CSS',
#  'IT,Html,CSS,React,Vue',
#  'HTML,CSS,React,Vue',
#  'IT',
#  'JavaScript,Html,CSS,Vue',
#  'JavaScript,Html',
#  'JAVA,Vue,Spring',
#  'React,Vue',
#  'Vue',
#  'JavaScript,HTML,React,Vue',
#  'IT,Vue',
#  'MCN',
#  'IT,JavaScript,Html,Vue',
#  'IT,JavaScript,HTML,CSS,Vue',
#  '',
#  'React,Vue',
#  'IT,Html,Vue',
#  'HTML,CSS,React,Vue',
#  'IT',
#  'IT',
#  'JavaScript,HTML,CSS,React,Angular',
#  'IT,JavaScript,HTML,React,Vue',
#  'JavaScript,Vue,MySQL',
#  'IT,JavaScript,Web,Three,js',
#  'TypeScript,React,Node,js',
#  'IT,JavaScript,Redux,React,ES',
#  'JavaScript,Html,HTML,Javascript,Vue',
#  'Vue',
#  'JavaScript,React',
#  'Html,CSS,React,Vue',
#  'Vue',
#  'Vue,JavaScript,uniapp',
#  'JAVA,JavaScript,CSS,React,Vue',
#  'JavaScript,HTML,CSS',
#  'JavaScript,HTML,CSS,Vue',
#  'JavaScript,Angular',
#  'Html,React,Vue',
#  'Vue,React,Html,HTML,CSS',
#  'IT',
#  'JAVA,JavaScript,HTML,CSS',
#  'JavaScript,TypeScript',
#  '',
#  'HTML,Html,CSS,Vue',
#  'Vue',
#  'JavaScript,HTML',
#  'Vue',
#  'React,Redux,Android',
#  'MCN,JavaScript,HTML,Html,CSS',
#  'Vue',
#  'HTML,CSS,Vue,Node,js',
#  'HTML,CSS,React,Vue',
#  'JavaScript,CSS,Vue,Spring,MySQL',
#  'CSS',
#  'IT',
#  'JavaScript,HTML,React,Vue,Angular',
#  'Vue,Node,js',
#  'Vue',
#  'Web',
#  'IT,Html,CSS,React,Vue',
#  'Vue',
#  'JavaScript,Html',
#  'HTML,Vue,Node,js',
#  'Vue',
#  'JavaScript,HTML,CSS,Vue,React',
#  '',
#  'IT,JavaScript,HTML,Vue,React,native',
#  'IT,JavaScript,React,Angular,Javascript',
#  'IT,JavaScript,HTML,Vue',
#  'IT,JavaScript,Angular,React,Vue',
#  'HTML,CSS,JavaScript,Angular,React',
#  'IT,JavaScript,Html,React,Vue',
#  'JavaScript,HTML,CSS',
#  'Html,Web',
#  'IT,Html,Vue',
#  'IT,JavaScript,Html,React,native',
#  'JavaScript,TypeScript,CAD,WebGL',
#  'JavaScript,TypeScript,XML',
#  'Html,Angular',
#  ...]

# %%
# [\u4e00-\u9fa5]+
jobDes = []
for i in data['jobDes']:
    jobDes.append(",".join(re.findall(re.compile(r'[\u4e00-\u9fa5]+'),i)))

# %%
jobDes
# Out:
# ['金融央企,六险二金,工会福利,专业通道',
#  '五险一金,年终奖,生日福利,节日福利等',
#  '央企,五险一金,年休假,绩效奖金,工会福利',
#  '周末双休,带薪年假,全勤奖,餐补,五险一金等',
#  '六险一金,完善的福利体制',
#  '公司氛围好',
#  '补充公积金',
#  '免费体检,每年两次调薪,年终奖,加班少',
#  '周末双休,带薪年假,五险一金,下午茶',
#  '六险一金,周末双休,节假日不补班',
#  '氛围好,成长快,五险一金,弹性工作',
#  '发展前景好',
#  '大神指导,五险一金,周末双休,丰厚年终',
#  '五险一金,做五休二,不加班,团队氛围好',
#  '绝佳办公环境,无,国企体制',
#  '五险一金,发展前景,员工生日会',
#  '周末双休,五险一金',
#  '周末双休,扁平化管理',
#  '下午茶,健身瑜伽,六险一金,五险一金',
#  '扁平化管理',
#  '年假,天,拒绝打卡,没有加班,技术流,大平台',
#  '早期成员,施展空间大,工业软件,发展前景好',
#  '深耕运营商通信行业,年,产品市场名列前沿',
#  '发展前景,平台稳定,保障齐全,人性化',
#  '五险一金,季度奖,年终奖,各种法定节假日',
#  '五险一金,带薪年假,年轻团队',
#  '发展前景好,团队建设齐全',
#  '网络信息安全行业前景好,团队氛围好',
#  '上市公司,五险一金,弹性打卡',
#  '五险一金,晋升快,带薪年假,体检,旅游',
#  '五险一金,周末双休,年底双薪,定期体检',
#  '五险一金,带薪年假,年轻团队',
#  '网络信息安全行业前景好,团队氛围好',
#  '上市公司,五险一金,弹性打卡',
#  '五险一金,周末双休,节日礼品,年度体检',
#  '扁平管理,周末双休,全勤奖,餐补,年终奖',
#  '双休,六险一金,晋升空间大,福利好',
#  '互联网公司,大咖多,氛围好,福利优厚',
#  '带薪年假,五险一金,扁平管理,岗位晋升',
#  '六险二金,平台大,扁平化管理,央企福利',
#  '晋升空间大,带教多',
#  '五险一金,年终奖金,带薪年假,节日福利',
#  '五险一金,免费工作餐,年节福利,年终奖金',
#  '福利待遇好,办公环境美,团队气氛佳',
#  '五险一金,年终奖金,带薪年假,节日福利',
#  '五险一金,免费工作餐,年节福利,年终奖金',
#  '六险一金,带薪年假,绩效奖金,体检',
#  '牛人带队,扁平化管理,成长空间',
#  '五险一金,双休',
#  '亿级用户量平台,高并发,自研产品',
#  '地铁旁,前景好,培训多',
#  '弹性工作时间,待遇优越',
#  '双休,六险一金,晋升空间大,福利好',
#  '大团队,核心业务',
#  '待遇好,发展前景好,领导团队非常',
#  '金融支付',
#  '五险一金,每年两次调薪,旅游,体检,年终奖等',
#  '发展空间很大,关爱员工,不定期举办活动',
#  '五险二金,带薪年假,工会福利,教育培训',
#  '亿级用户量平台,高并发,自研产品',
#  '上市公司,多次调薪,五险一金,双休',
#  '六险一金,一档社保,地铁周边,加班有偿',
#  '福利待遇好,办公环境美,团队气氛佳',
#  '周末双休,福利待遇好',
#  '上市公司,福利全面,重点项目',
#  '上市公司,福利全面',
#  '股票期权,灵活办公',
#  '双休,六险一金,晋升空间大,福利好',
#  '央企',
#  '弹性工作,周末双休',
#  '牛人带队,扁平化管理,成长空间',
#  '发展前景',
#  '带薪年假,五险一金,扁平管理,岗位晋升',
#  '平台好,弹性工作,上市企业',
#  '内研产品竞争强,福利待遇好',
#  '股票期权,灵活办公',
#  '五险一金,双休,培训,加班补贴,年度体检',
#  '五险一金,专业培训,双薪奖金,超长年假',
#  '央企',
#  '上市公司,工作环境',
#  '双休',
#  '六险一金,一档社保,地铁周边,加班有偿',
#  '网络信息安全行业前景好,团队氛围好',
#  '晋升快',
#  '稳定',
#  '五险一金,每年两次调薪,旅游,体检,年终奖等',
#  '试用期全额,补充医疗保险,不打卡,带薪年假',
#  '晋升快',
#  '弹性工时,季度奖,年底,餐补,车补',
#  '五险一金,周末双休,节日礼品,年度体检',
#  '弹性工时,季度奖,年底,餐补,车补',
#  '团队氛围好',
#  '不加班,有年终奖',
#  '发展空间大,独角兽,扁平化管理',
#  '不定期团建,五险一金',
#  '大平台,大神多,福利待遇好',
#  '大牛带队,试用期不打折,加班少,团队好,双休',
#  '周末双休,福利待遇好',
#  '发展前景好',
#  '福利待遇好',
#  '五险一金,餐补话补,周末双休,定期体检',
#  '周末双休,年终奖,加班费',
#  '五险一金',
#  '发展前景好',
#  '带薪年假,五险一金,扁平管理,岗位晋升',
#  '股票期权,灵活办公',
#  '工作环境舒适,福利待遇优越,同事关系融洽',
#  '年终奖',
#  '项目奖,年终奖,月度聚餐,节日福利,旅游',
#  '环境优雅,扁平化管理,晋升通道完善,股权激励',
#  '环境优雅,扁平化管理,晋升通道完善,股权激励',
#  '前景好,待遇好',
#  '周末双休,年终奖,加班费',
#  '可居家办公,年龄不设上限',
#  '大牛团队,福利好,氛围好',
#  '大团队,核心业务',
#  '重点园区,亿级项目,区块链创新应用',
#  '银行金融行业',
#  '不加班,前景好',
#  '高并发,大数据量,分布式,团建,团队年轻',
#  '五险一金,生活补贴,薪,周末双休绩效年终奖',
#  '上市企业,五险一金,周末双休',
#  '房交通补,父母子女金,五险一金,周末双休',
#  '金融支付',
#  '晋升,培训',
#  '项目奖金,五险一金,包三餐',
#  '五险一金,每年两次调薪,旅游,体检,年终奖等',
#  '年终奖金,扁平管理,年度体检,晋升空间',
#  '互联网金融,大平台,项目多样,技术紧跟趋势',
#  '晋升快',
#  '大厂平台',
#  '银行,稳定',
#  '不定期团建,五险一金',
#  '五险一金,周末双休,节日礼品,年度体检',
#  '充满活力和协作的办公环境',
#  '试用期薪资不打折,五险一金,季度奖金',
#  '年终奖',
#  '金融科技引领时代潮流',
#  '弹性时间,大牛多,奖金多',
#  '试用期全额,补充医疗保险,不打卡,带薪年假',
#  '银行金融行业',
#  '大牛带队,试用期不打折,加班少,团队好,双休',
#  '大神带教薪资高',
#  '银行,稳定',
#  '不定期团建,五险一金',
#  '大平台,大神多,福利待遇好',
#  '上市公司,朝九晚六,腾讯投资,行业',
#  '发展前景高,团队技术氛围浓厚',
#  '试用期薪资不打折,五险一金,季度奖金',
#  '负责前沿的物联网产品后台研发',
#  '央企实力,工业互联网,薪酬福利有竞争力',
#  '福利健全,大平台',
#  '金融',
#  '发展前景好',
#  '氛围好,包三餐,环境好,不打卡,成长快',
#  '六险一金,年度体检,下午茶',
#  '通讯补贴,餐补,加班补贴,季度奖金,项目奖金',
#  '大神带教薪资高',
#  '平台大,福利好',
#  '五险一金,弹性工作,绩效奖金,周末双休',
#  '工作环境舒适,福利待遇优越,同事关系融洽',
#  '内研产品竞争强,福利待遇好',
#  '大牛团队,福利好,氛围好',
#  '六险一金',
#  '双休',
#  '周末双休',
#  '五险一金',
#  '重点园区,亿级项目,区块链创新应用',
#  '银行科技,国际化',
#  '金融科技引领时代潮流',
#  '双休,年终',
#  '试用期全额,补充医疗保险,不打卡,带薪年假',
#  '薪资优厚,平台稳定,团队完整,氛围轻松',
#  '平台大,福利好',
#  '房交通补,父母子女金,五险一金,周末双休',
#  '通讯补贴,餐补,加班补贴,季度奖金,项目奖金',
#  '环境优雅,扁平化管理,晋升通道完善,股权激励',
#  '国高新,项目奖金,各项补助',
#  '银行项目,稳定',
#  '银行金融行业',
#  '可居家办公,年龄不设上限',
#  '七险一金,定期团建,年度体检',
#  '五险一金,周末双休,节日礼品,年度体检',
#  '发展前景高,团队技术氛围浓厚',
#  '央企,福利好,前景广阔',
#  '年终奖六险一金饭贴车贴绩效奖定期体检聚餐',
#  '试用期薪资不打折,五险一金,季度奖金',
#  '年终奖',
#  '大神指导,周末双休,丰厚年终奖',
#  '开发',
#  '六险一金,团队优秀,超长年假,团建活动',
#  '公司平台',
#  '工作稳定,发展前景好,五险一金,双休,年假',
#  '项目激励,晋升空间',
#  '高速发展,风口赛道,福利丰厚,扁平管理',
#  '绩效奖,年终奖,团体意外险,成长津贴,体检',
#  '六险一金',
#  '税后薪资,弹性工作,年终分红',
#  '周末双休',
#  '前沿技术,弹性工作,五险一金,牛人共同工作',
#  '上市企业,银行项目',
#  '银行科技,国际化',
#  '双休,年终',
#  '全薪年假,周末双休,团建出游,大牛团队',
#  '发展前景',
#  '五险一金,节日福利',
#  '自主研发,周末双休,五险一金,年度体检',
#  '银行项目,稳定',
#  '环境优雅,扁平化管理,晋升通道完善,股权激励',
#  '可居家办公,年龄不设上限',
#  '住宿,餐补',
#  '五险一金,节假日福利,团建旅游,晋升空间大',
#  '开发',
#  '发展前景好',
#  '大牛团队,福利好,氛围好',
#  '定期团建',
#  '上市公司,朝九晚六,腾讯投资,行业',
#  '不加班,双休,五险一金,薪,独栋大厦,领导好',
#  '周末双休,法定节假日,带薪年休假',
#  '弹性工作,内部培训,技术挑战,年底多薪',
#  '周末双休,五险一金,年终奖金,年度调薪',
#  '互联网金融',
#  '福利待遇优厚,发展前景好,国企集团下属公司',
#  '项目激励,晋升空间',
#  '轻松活跃',
#  '绩效奖,年终奖,团体意外险,成长津贴,体检',
#  '季度绩效补贴,加班费',
#  '领导,团队大牛多,弹性工作',
#  '五险一金,高温补贴,餐补,双休',
#  '银行项目',
#  '六险一金',
#  '试用期全额,补充医疗保险,不打卡,带薪年假',
#  '早期成员,施展空间大,工业软件,发展前景好',
#  '五险一金,周末双休,节日礼品,年度体检',
#  '五险一金,免费班车,绩效奖金,节日福利,餐饮',
#  '五险一金,节日福利公司团建绩效年终奖不加班',
#  '试用期薪资不打折,五险一金,季度奖金',
#  '五险一金,双休',
#  '国际化团队,不打卡,年假多,福利好',
#  '大神指导,周末双休,丰厚年终奖',
#  '六险一金,周末双休,弹性打卡',
#  '晋升空间大,五险一金,年底奖金,员工体检',
#  '全球外资企业平台,牛人大咖云集',
#  '发展前景大',
#  '公司平台',
#  '周末双休,稳定,领导',
#  '工作稳定,发展前景好,五险一金,双休,年假',
#  '核心项目,技术大牛坐阵,学投资,大公司福利好',
#  '定期团建',
#  '七险一金,定期团建,年度体检',
#  '公司氛围好',
#  '团队氛围好,发展空间大',
#  '地方政府合作项目,业务稳定',
#  '高速发展,风口赛道,福利丰厚,扁平管理',
#  '周末双休,弹性工作时间,薪年终奖',
#  '主站核心团队',
#  '发展空间大',
#  '周末双休,五险一金,地铁周边,年轻团队',
#  '早九晚六,周末双休',
#  '税后薪资,弹性工作,年终分红',
#  '五险一金,工作稳定',
#  '五险一金,节日福利',
#  '央企,福利好,前景广阔',
#  '弹性工作,内部培训,技术挑战,年底多薪',
#  '带薪年假,节日补贴,高低温补贴,年度体检',
#  '六险一金,企业年金,居家办公,外企氛围',
#  '下午茶,健身瑜伽,六险一金,五险一金',
#  '餐费补贴',
#  '五险一金',
#  '自由灵活,大牛带队,带薪年休假,各类福利',
#  '环境优雅,扁平化管理,晋升通道完善,股权激励',
#  '核心项目,平台大,稳定',
#  '季度绩效补贴,加班费',
#  '可居家办公',
#  '五险一金,带薪年假,定期体检,绩效奖金',
#  '业务前景大,薪酬福利待遇好,成长上升空间大',
#  '五险一金,节假日福利,团建旅游,晋升空间大',
#  '待遇优',
#  '成长型团队,资深大牛,领导',
#  '双休,年终',
#  '全薪年假,周末双休,团建出游,大牛团队',
#  '工作稳定,前景好,隶属于上汽云计算中心',
#  '六险一金部门聚餐定期体检过节费年终奖双休',
#  '清华团队,年终奖金,个月,五险一金',
#  '团队年轻化,福利好,高新企业,拟上市公司',
#  '自有产研团队,氛围轻松',
#  '早九晚六,双休,五险一金',
#  '弹性工作,六险一金,无加班文化',
#  '五险一金,带薪年假,定期体检,绩效奖金',
#  '五险一金,双休,国企',
#  '五险一金,免费班车,绩效奖金,节日福利,餐饮',
#  '五险一金节日福利,公司团建,周末双休',
#  '五险一金,节日福利公司团建绩效年终奖不加班',
#  '绩效奖,年终奖,团体意外险,成长津贴,体检',
#  '福利待遇优厚,发展空间大,团队氛围好',
#  '试用期全额,补充医疗保险,不打卡,带薪年假',
#  '清华团队,年终奖金,个月,五险一金',
#  '定期团建',
#  '发展前景好',
#  '团队,个人快速发展过程中',
#  '福利齐全,一年两次涨薪',
#  '可居家办公',
#  '五险一金,周末双休,午餐补助',
#  '五险一金,双休,餐补,季度奖金',
#  '可居家办公',
#  '弹性工作,六险一金,无加班文化',
#  '五险一金,员工下午茶,周末双休',
#  '周末双休,年终奖,加班费',
#  '何田教授带领的京东物流人工智能与大数据部',
#  '金融科技',
#  '下午茶,健身瑜伽,六险一金,五险一金',
#  '大项目,双休,入职五险一金商业保险',
#  '待遇优',
#  '项目优质,氛围好,双休',
#  '年底双薪,年终奖,过节费,五险一金,周末双休',
#  '五险一金,节假日福利,团建旅游,晋升空间大',
#  '年终,薪,股权激励,带薪年假,每年调薪',
#  '国企大平台',
#  '天年假,医疗报销,旅游津贴',
#  '公司平台大,发展前景好,团队有大牛',
#  '证券项目,提供两餐,月度奖金,节假日不补班',
#  '团队氛围好,技术',
#  '大平台,丰厚奖金',
#  '带薪年假,五险一金,扁平管理,岗位晋升',
#  '六险一金,弹性工作,带薪年假',
#  '带薪年假,五险一金,扁平管理,岗位晋升',
#  '年终奖,下午茶',
#  '福利齐全,晋升快,大平台',
#  '团队氛围好,行业前景好',
#  '周末双休',
#  '互联网金融',
#  '三餐,下午茶,五险一金,体检,班车,团建',
#  '薪,健康体检,六险一金,一档社保,定期调薪',
#  '项目奖金,五险一金,包三餐',
#  '年终奖',
#  '季度津贴,年底奖金,年度体检,年度两次调薪',
#  '办公环境舒适,双休,定期团建',
#  '国企,双休,加班少,五险一金,对接本部领导',
#  '银行外包驻场',
#  '年终绩效,双休,晋升,六险一金,旅游,团队好',
#  '发展潜力强',
#  '工作稳定,前景好,隶属于上汽云计算中心',
#  '北京户口,五险一金,双休',
#  '五险一金,环境,交通补贴,团建',
#  '银行,金融',
#  '团队年轻化,福利好,高新企业,拟上市公司',
#  '重点园区,亿级项目,区块链创新应用',
#  '五险一金,朝九晚六双休',
#  '待遇好,发展前景好,领导团队非常',
#  '调薪,周末双休,五险一金,年终奖',
#  '上市公司,大平台,自有产品',
#  '中国电子科学研究院,央企合同工',
#  '倍加班费,六险一金,个月年终奖',
#  '五险一金,节日福利,带薪年假,团队氛围好',
#  '良好的工作环境,宽松的工作氛围',
#  '银行外包驻场',
#  '带薪年假,团队合作',
#  '上市企业,优秀团队',
#  '六险一金,项目稳定性高,央企二级子公司',
#  '国企平台,福利待遇好',
#  '热门行业,团队伙伴优秀',
#  '公司有多个,创新项目,未来发展前景广阔',
#  '发展前景大,周末双休,六险一金,外企平台',
#  '大厂项目,长期稳定',
#  '双休',
#  '我们有竞争力的薪资制度,天假期福利',
#  '周末双休,五险一金,法定节假日不补班,加班少',
#  '年假,天,拒绝打卡,没有加班,技术流,大平台',
#  '公司自有产品,餐饮补贴,交通补贴,通讯补贴',
#  '晋升空间大,福利待遇好',
#  '上班,天,小时工作制,周末双休',
#  '弹性时间,大牛多,奖金多',
#  '扁平化管理,技术氛围浓厚',
#  '技术大牛,定期团建,福利齐全',
#  '团队氛围好,免费三餐,租房补贴',
#  '团队氛围好,接触新项目,技术沉淀',
#  '六险一金,周末双休',
#  '大牛带队,试用期不打折,加班少,团队好,双休',
#  '团队氛围好,接触新项目,技术沉淀',
#  '薪资福利好',
#  '周末双休,入职缴纳五险一金',
#  '央企本部,长期稳定,核心技术',
#  '业务好,发展空间大',
#  '精英团队,福利待遇好,奖金丰厚,晋升通道清晰',
#  '下午茶,团队氛围好,用户过亿,免费三餐',
#  '行业发展前景好',
#  '驻场银行,长期稳定,不加班',
#  '银行,金融科技',
#  '内研产品竞争强,福利待遇好',
#  '发展前景',
#  '前景可期,团队核心',
#  '待遇高,福利好,机会多,空间大',
#  '年终奖,周末双休,加班费,大牛平台',
#  '下午茶,健身瑜伽,六险一金,五险一金',
#  '五险一金',
#  '牛人带队',
#  '前沿技术,弹性工作,五险一金,无人机',
#  '和有趣的人一起做有趣的事儿',
#  '五险一金,晋升机会,奖金丰厚',
#  '双休,技术提升,大牛带领',
#  '发展前景好',
#  '五险一金',
#  '晋升空间大,福利待遇好',
#  '双休',
#  '技术社区',
#  '上市公司,薪,每年涨薪,住宿加差补',
#  '双休,年假,五险一金,长期稳定',
#  '五大行,核心技术,周末双休,告别',
#  '下午茶,健身瑜伽,六险一金,五险一金',
#  '工作生活平衡',
#  '薪资优厚,平台稳定,团队完整,氛围轻松',
#  '大企业',
#  '央企背景,六险二金,节假日福利,扁平化管理',
#  '风口行业,交通便利,团队氛围,牛人导师',
#  '知名大厂,包住',
#  '核心开发,最新技术',
#  '项目奖金,五险一金,餐补,交通补助,通讯补助',
#  '七险两金,发展平台',
#  '个性化职业发展规划,团队作战,一对一辅导',
#  '可就近安排工作',
#  '双休,五险一金,餐补房补,食堂,发薪早,加班少',
#  '大平台,快速发展',
#  '现金补贴,超额利润奖,六险一金',
#  '发展空间大,福利待遇好',
#  '五险一金,弹性工作,绩效奖金,周末双休',
#  '行业前景好',
#  '通讯补贴,餐补,加班补贴,季度奖金,项目奖金',
#  '国企,大平台,稳定,双休,朝九晚六,六险一金',
#  '牛人团队,外企氛围晋升空间大',
#  '节日福利,职工食堂',
#  '行业前景好,工作氛围和谐',
#  '发展前景良好',
#  '扁平化管理,弹性工作制,福利正规',
#  '有竞争力的薪资,双休,六险一金',
#  '海外游戏玩不停,最酷的,平台',
#  '数字化工厂',
#  '朝阳行业,发展空间大,团队氛围好,福利待遇好',
#  '周末双休,年底双薪,下午茶,弹性工作',
#  '签字现金,入职股票,年假充裕,外企风格',
#  '专人带教',
#  '五险二金,带薪年假,工会福利,教育培训',
#  '技术团队,阿里背景技术',
#  '出国工作机会,跨国同事合作,团队氛围好',
#  '五险一金,餐补,弹性工作,上市公司',
#  '双休,高薪',
#  '朝阳行业,产品落地,高速发展中',
#  '央企稳定,五险一金',
#  '五险一金一档,节日礼品,大小周',
#  '公司发展快速,薪酬待遇优厚,参与全球项目',
#  '六险二金,通讯补贴,餐补,免费培训',
#  '团队氛围佳,寻找有冲劲的你',
#  '客户系统',
#  '年轻公司,发展空间广,五险一金,员工氛围好',
#  '早餐下午茶,节日福利,提供住房补助',
#  '',
#  '办公环境氛围好发展前景好',
#  '远程',
#  '发展前景好',
#  '弹性上班,周末双休,五险一金,年底双薪',
#  '工作氛围',
#  '华为,招聘,一年后有机会转正式华为员工',
#  '资深开发人员负责培训和技术指导',
#  '浪桥科技,轮融资,年,开发经验',
#  '薪资,英语可做工作语言',
#  '提供住宿,免费早餐,班车接送,五险一金',
#  '实事求是,合适就来',
#  '福利很好哦',
#  '互联网公司,大咖多,氛围好,福利优厚',
#  '正式编制,平台稳定,五险一金',
#  '工程师文化',
#  '薪,扁平管理,股票期权,六险一金',
#  '下午茶,健身瑜伽,六险一金,五险一金',
#  '福利好,氛围佳',
#  '五险一金,交通补助,通讯补助,周末双休',
#  '下午茶,健身瑜伽,团队氛围好,扁平管理',
#  '五险一金,周六日双休,扁平管理',
#  '五险一金,定期体检,节日福利',
#  '下午茶,健身瑜伽,六险一金,五险一金',
#  '五险一金,商业保险,带薪年假,健康体检,餐补',
#  '英语环境办公',
#  '五险一金',
#  '发展空间大,达成,按月发放奖金',
#  '国际化团队,竞争性薪酬,晋升空间大',
#  '行业标杆,氛围好,团队棒,前景广',
#  '出海,绩效奖金,双休,班车接送,定期体检',
#  '年终奖,个月',
#  '平台大,上司,福利多多,周末双休',
#  '新员工周转宿舍,年员工持股,股份分红',
#  '业务重点,晋升空间大',
#  '发展前景,薪酬待遇',
#  '下午茶,健身瑜伽,六险一金,五险一金',
#  '下午茶,健身瑜伽,五险一金,股票期权',
#  '扁平化,前景好',
#  '福利待遇好,奖金丰厚',
#  '国企背景,大平台,福利多多',
#  '发展前景大,工作氛围自由平等,周末双休',
#  '团队实力,包三餐,房补',
#  '年轻公司,发展空间广,六险一金,员工氛围好',
#  '国网营销',
#  '团队气氛佳',
#  '专业团队',
#  '技术氛围好,专业管理培训,周末双休,奖金丰厚',
#  '弹性工作薪资,大牛云集',
#  '上市公司',
#  '团队氛围好',
#  '核心业务,技术大牛,六险一金,免费班车',
#  '强集团科技公司,发展前景广阔',
#  '集团总部职位,平台好,核心团队',
#  '核心项目,教育,游戏朝阳产业',
#  '薪酬待遇',
#  '拼多多',
#  '广汽平台,数字化核心团队,福利好',
#  '广汽平台,数字化核心团队,福利好',
#  '技术氛围好,空间大',
#  '扁平化',
#  '作为团队领导者',
#  '全额公积金,双休,包三餐',
#  '六险一金,弹性工作,扁平管理',
#  '五险二金,免饭,宿舍班车,技术驱动',
#  '细分头部,独立开发,发展空间大,技术氛围好',
#  '海外营销,新媒体',
#  '好平台,潜力大',
#  '周末双休',
#  '发展前景',
#  '国家电信项目,五险一金',
#  '国家电信项目,五险一金',
#  '办公环境优,团队氛围好,后,扁平管理',
#  '核心业务,发展巨大,薪资高',
#  '自由',
#  '自由',
#  '五险一金,绩效奖金,带薪休假,体检,节日福利',
#  '五险年底双薪,绩效奖金,定期体检,带薪年假',
#  '大型,企业',
#  '公司发展前景大,福利待遇优',
#  '公司发展前景大,福利待遇优',
#  '绩效奖金,弹性工作,五险一金,带薪年假',
#  '内部晋升,年度体检,周末双休',
#  '合伙制,技术合伙人,弹性工作,股票期权',
#  '大平台',
#  '无,平台前沿',
#  '扁平化管理',
#  '完善的薪酬福利体系,良好的发展空间',
#  '双通道晋升',
#  '六险一金,周末双休,带薪年假,定期体检',
#  '',
#  '晋升制度明确,节假日福利保障充分',
#  '免费三餐',
#  '连续成功创业团队,公司氛围好,全员',
#  '创新项目',
#  '团队氛围好',
#  '大厂经历,健身房,免费早餐',
#  '提供实习证明,免费零食供应,可转正',
#  '双体,带薪休假,年底奖金,五险',
#  '下午茶,健身瑜伽,五险一金,股票期权',
#  '下午茶,健身瑜伽,六险一金,团队氛围好',
#  '架构团队',
#  '国家项目,五险一金,加班补助,周末双休',
#  '',
#  '和谐团队氛围,竞争力的薪资',
#  '我们拒绝,我们追求高效完成工作',
#  '大平台',
#  '双休,薪',
#  '不加班,不出差',
#  '最大程度提高开发效率',
#  '下午茶,健身瑜伽,六险一金,团队氛围好',
#  '下午茶,健身瑜伽,六险一金,五险一金',
#  '下午茶,健身瑜伽,六险一金,五险一金',
#  '下午茶,六险一金,带薪休假,扁平管理',
#  '下午茶,健身瑜伽,六险一金,五险一金',
#  '下午茶,健身瑜伽,六险一金,五险一金',
#  '下午茶,健身瑜伽,六险一金,五险一金',
#  '下午茶,健身瑜伽,六险一金,五险一金',
#  '下午茶,健身瑜伽,六险一金,团队氛围好',
#  '下午茶,健身瑜伽,六险一金,股票期权',
#  '下午茶,健身瑜伽,六险一金,五险一金',
#  '下午茶,健身瑜伽,六险一金,五险一金',
#  '下午茶,健身瑜伽,六险一金,五险一金',
#  '六险一金,大牛带队,健身瑜伽,用户过亿',
#  '弹性工作,免费三餐,下午茶,晋升空间大',
#  '下午茶,团队氛围好,扁平管理,大牛带队',
#  '下午茶,健身瑜伽,六险一金,五险一金',
#  '下午茶,健身瑜伽,六险一金,五险一金',
#  '下午茶,健身瑜伽,六险一金,五险一金',
#  '下午茶,健身瑜伽,六险一金,股票期权',
#  '下午茶,团队氛围好,晋升空间大',
#  '下午茶,健身瑜伽,六险一金,五险一金',
#  '下午茶,健身瑜伽,六险一金,五险一金',
#  '下午茶,健身瑜伽,六险一金,五险一金',
#  '下午茶,六险一金,扁平管理,用户过亿',
#  '下午茶,健身瑜伽,六险一金,五险一金',
#  '下午茶,健身瑜伽,六险一金,团队氛围好',
#  '下午茶,六险一金,团队氛围好,带薪休假',
#  '弹性工作,免费三餐,五险一金,租房补贴',
#  '六险一金,弹性工作,免费三餐,租房补贴',
#  '六险一金,股票期权,弹性工作,免费三餐',
#  '团队氛围好,扁平管理,大牛带队',
#  '团队氛围好,扁平管理,大牛带队',
#  '六险一金,股票期权,弹性工作,免费三餐',
#  '下午茶,健身瑜伽,六险一金,五险一金',
#  '下午茶,健身瑜伽,六险一金,扁平管理',
#  '下午茶,健身瑜伽,六险一金,扁平管理',
#  '六险一金,五险一金,团队氛围好,餐补',
#  '六险一金,五险一金,团队氛围好,餐补',
#  '下午茶,健身瑜伽,六险一金,五险一金',
#  '下午茶,健身瑜伽,六险一金,股票期权',
#  '下午茶,健身瑜伽,六险一金,股票期权',
#  '六险一金,股票期权,弹性工作,免费三餐',
#  '六险一金,团队氛围好,晋升空间大',
#  '六险一金,股票期权,弹性工作,免费三餐',
#  '六险一金,团队氛围好,五险一金,餐补',
#  '六险一金,租房补贴,带薪休假,弹性工作',
#  '六险一金,弹性工作,免费三餐,租房补贴',
#  '扁平管理,六险一金,健身瑜伽,下午茶',
#  '租房补贴,扁平管理,职业大牛,团队氛围好',
#  '租房补贴,扁平管理,职业大牛,团队氛围好',
#  '用户过亿,大牛带队',
#  '六险一金,股票期权,团队氛围好',
#  '下午茶,六险一金,带薪休假,扁平管理',
#  '下午茶,六险一金,免费三餐,弹性工作',
#  '下午茶,健身瑜伽,六险一金,五险一金',
#  '下午茶,健身瑜伽,六险一金,五险一金',
#  '下午茶,健身瑜伽,股票期权,团队氛围好',
#  '下午茶,健身瑜伽,股票期权,团队氛围好',
#  '下午茶,健身瑜伽,六险一金,五险一金',
#  '六险一金,团队氛围好,晋升空间大',
#  '下午茶,健身瑜伽,六险一金,股票期权',
#  '下午茶,健身瑜伽,团队氛围好,大牛带队',
#  '下午茶,健身瑜伽,团队氛围好,大牛带队',
#  '下午茶,六险一金,团队氛围好,免费三餐',
#  '免费三餐,租房补贴,用户过亿,大牛带队',
#  '下午茶,健身瑜伽,团队氛围好,扁平管理',
#  '奖金福利,出国机会,高薪,办公',
#  '发展前景好,团队实力强,带薪年假,六险一金',
#  '带薪年假,周末双休,六险一金,定期体检',
#  '氛围好,大牛云集,上升空间大',
#  '团队年轻化,年度体检',
#  '发展前景好,上升空间大,氛围好,弹性工作',
#  '工业和信息化部直属事业单位',
#  '弹性上下班时间,办公环境好,交通便利',
#  '外企氛围,人才密度高,成长空间大',
#  '五险一金,补充医疗,各种补贴,弹性上下班',
#  '五险一金',
#  '高起薪,有工程师带',
#  '双休,五险一金,节日福利,年终奖,带薪年假',
#  '五险一金,气氛好',
#  '腾讯,乡村振兴项目,薪资高有项目奖',
#  '项目分红,双休,股权期权,研发经验',
#  '七险二金,发展平台',
#  '真刀真枪,路径灵活,年轻人的',
#  '真刀真枪,路径灵活,年轻人的',
#  '科技金融,前景很好',
#  '五险一金,扁平化管理,不加班',
#  '发展前景',
#  '五险一金,周末双休,晋升空间大,行业前沿',
#  '发展前景好',
#  '六险一金,福利好,大平台,大项目',
#  '轮融资',
#  '天带薪年假,六险一金,周末双休不加班打卡',
#  '最新的技术,大牛指导,不用加班,奖金保障',
#  '精通,与',
#  '带薪年假,五险一金,节日福利,年终奖金,双休',
#  '前景好,福利多,氛围棒',
#  '发展前景,福利待遇,五险一金,年终奖',
#  '技术提升快,弹性工作',
#  '发展前景,福利待遇,五险一金,年终奖',
#  '氛围好,工资待遇优',
#  '六险一金,天带薪年假,个月试用期',
#  '天年假,补充保险,试用期全额,周末双休',
#  '可居家办公,年龄不设上限',
#  '稳定',
#  '可居家办公,年龄不设上限',
#  '五险一金,定期体检,员工旅游,节日福利',
#  '双休,各节日礼品,生日礼金',
#  '五险一金,节日福利',
#  '天带薪年假,六险一金,周末双休不加班打卡',
#  '技术分享,带薪假期,晋升机会,年终奖',
#  '技术大牛,团队氛围轻松,领导',
#  '弹性工作,交通便利,办公环境好',
#  '足额购买五险一金,补充医疗,年假,节日福利',
#  '技术提升快,弹性工作',
#  '可居家办公,不设年龄上限',
#  '氛围好,大牛云集',
#  '清华团队,年终奖金,个月,五险一金',
#  '晋升空间,五险一金',
#  '可居家办公,年龄不设上限',
#  '前景好,福利多,氛围棒',
#  '发展前景,福利待遇,五险一金,年终奖',
#  '六险一金,天带薪年假,个月试用期',
#  '技术大牛,上升空间大',
#  '五险一金,交通补助,话费补助',
#  '周末双休,六险一金,超长年假,福利多多',
#  '六险一金,带薪年假,综合补贴',
#  '班车餐补,周末双休,上市集团,年假',
#  '技术大牛,团队氛围轻松,领导',
#  '管理扁平,氛围和谐,技术大牛',
#  '平台可塑性强,技术成长快,团队默契',
#  '天带薪年假,六险一金,周末双休不加班打卡',
#  '六险一金,绩效奖金,年度体检,福利丰富',
#  '双休不加班,团队氛围好,技术提升快',
#  '五险一金,周末双休,季度奖金,项目补助',
#  '行业前景好,公司氛围棒,福利多多,晋升空间大',
#  '股,餐补,项目奖金,周末双休',
#  '上市公司,重点项目,福利全面',
#  '自研项目,项目稳定,朝九晚六',
#  '早期成员,施展空间大,工业软件,发展前景好',
#  '六险一金,带薪旅游,定期团建,下午茶等',
#  '地铁边,前景好,待遇优',
#  '五险一金,餐补,薪',
#  '前端',
#  '带薪年假,五险一金,周末双休',
#  '发展前景',
#  '国家政策标准研究项目',
#  '项目稳定,季度奖金',
#  '前景好,福利多,氛围棒',
#  '发展前景,福利待遇,五险一金,年终奖',
#  '六险一金,天带薪年假,个月试用期',
#  '技术大牛,上升空间大',
#  '弹性上班,周末双休,项目奖金',
#  '五险一金,弹性上班,团队',
#  '带薪年假,周末双休,节日福利',
#  '周末双休,五险一金',
#  '前端开发',
#  '人工智能,氛围好,扁平化,机会多,上海落户',
#  '双休,工作轻松稳定,有成长空间,五险一金',
#  '团队稳定,规模大',
#  '五险一金,周末双休',
#  '六险一金,带薪年假,综合补贴',
#  '五险一金,双休,节日福利,团队旅游',
#  '上市公司周末双休超高薪资五险一金晋升空间',
#  '扁平化管理,年轻团队氛围好',
#  '可居家办公,年龄不设上限',
#  '团队氛围佳,福利待遇好',
#  '技术大牛,团队氛围轻松,领导',
#  '双休,先进的技术栈,扁平化管理',
#  '天带薪年假,六险一金,周末双休不加班打卡',
#  '周末双休,入职购买五险一金,上市公司',
#  '未来可发展为项目经理或部门经理',
#  '公积金比例高,工作环境好',
#  '人工智能行业,企业',
#  '奖金',
#  '技术大拿,完善的培养通道',
#  '发展平台好',
#  '五险一金,餐补,薪',
#  '五险一金,年度体检,全勤奖,年底双薪',
#  '前景好,福利多,氛围棒',
#  '发展前景,福利待遇,五险一金,年终奖',
#  '前沿业务',
#  '六险一金,天带薪年假,个月试用期',
#  '六险一金,周末双休,节假日福利,绩效奖金',
#  '团队氛围佳,福利待遇好',
#  '五险一金,餐补',
#  '可居家办公,年龄不设上限',
#  '每年两次加薪机会,上升快,人很',
#  '五险一金,节日福利,氛围融洽',
#  '行业独角兽',
#  '公司,年,次调级调薪,团队特团结且有活力',
#  '团队氛围很好,领导',
#  '五险一金,技术大牛,团队氛围超级棒',
#  '团队稳定,规模大',
#  '扁平化,发展空间大,福利完善',
#  '美味三餐,免费班车接送,平台大,领导好',
#  '福利待遇好',
#  '六险一金,带薪年假,综合补贴',
#  '双休,五险一金,年度加薪',
#  '五险一金,双休,餐补',
#  '团队友好',
#  '天带薪年假,六险一金,周末双休不加班打卡',
#  '福利,奖金,股权激励,双休,团建,体检,旅游',
#  '天带薪假期',
#  '节假日福利',
#  '带薪年假,天,年终奖',
#  '五险一金,年终奖金,员工旅游,定期体检',
#  '五险一金,带薪休假,快速晋升',
#  '公司平台大,晋升机制透明,员工福利完善',
#  '双休',
#  '五险一金,餐补,薪',
#  '可居家办公,年龄不设上限',
#  '福利待遇好,年终奖金',
#  '前景好,福利多,氛围棒',
#  '发展前景,福利待遇,五险一金,年终奖',
#  '六险一金,周末双休,生日福利,带薪年假',
#  '团队稳定,规模大',
#  '上市公司,团队氛围好,成长空间大',
#  '福利待遇好',
#  '六险一金,带薪年假,综合补贴',
#  '团队友好',
#  '平台大,氛围良好,机会多,奖金多多',
#  '六险一金',
#  '大厂',
#  '福利,奖金,股权激励,双休,团建,体检,旅游',
#  '班车食堂,五险一金,补充公积金,年终奖,体检',
#  '平台大,福利好',
#  '腾讯专家团队,六险一金,弹性上班,氛围轻松',
#  '核心开发,全勤奖,免费班车,八险一金',
#  '五险一金,带薪年假,奖金,福利补贴,股票期权',
#  '发展前景,福利待遇,五险一金,年终奖',
#  '扁平化,下午茶,福利多,弹性,发展前景好',
#  '周末双休,带薪年假,五险一金,年终奖',
#  '扁平管理,双休,加薪福利,自研项目',
#  '有挑战的事,上升空间大',
#  '大牛带队,自研平台,弹性工作,待遇丰厚',
#  '带薪年假',
#  '带薪年假,年度体检,薪资福利好,弹性工作',
#  '五险一金,弹性工作,宽松环境',
#  '双休,带薪假,年假,晋升大,气氛融洽',
#  '福利待遇好',
#  '技术大牛,优秀团队',
#  '五险一金,带薪休假,岗位晋升',
#  '平台大,氛围良好,机会多,奖金多多',
#  '非外包,弹性工作制,不要求',
#  '国家高新企业,人工智能企业,蓝海市场',
#  '阿里旗下,团队',
#  '福利,奖金,股权激励,双休,团建,体检,旅游',
#  '不加班,清闲,稳定',
#  '上市企业,独立办公大楼,薪,团队',
#  '不加班,国际化团队,可在家办公,文化好',
#  '周末双休,早餐补贴,包中餐,年终奖金',
#  '职位发展空间,领导好',
#  '氛围好,晋升通道,股权,行业前景好,自研产品',
#  '六险二金,上五休二,交通,餐补,健身房,班车',
#  '北大博士,腾讯大牛,电竞大数据,期权激励',
#  '五险一金,年终绩效,餐补',
#  '将与一群优秀,有才有趣有理想的同事共事',
#  '福利好,平台大',
#  '发展空间大,工作氛围佳,扁平化管理',
#  '五险一金,带薪年假,奖金,福利补贴,股票期权',
#  '发展前景,福利待遇,五险一金,年终奖',
#  '扁平化,下午茶,福利多,弹性,发展前景好',
#  '上市公司,大牛带队,福利完善',
#  '周末双休,带薪年假,五险一金,年终奖',
#  '奖金福利,出国机会,高薪,办公',
#  '有挑战的事,上升空间大',
#  '平台大,领导好,项目牛,技术强,成长发展快',
#  '央企稳定平台',
#  '大牛带队,自研平台,弹性工作,待遇丰厚',
#  '带薪年假,年度体检,薪资福利好,弹性工作',
#  '福利待遇,发展前景',
#  '双休,带薪假,年假,晋升大,气氛融洽',
#  '福利待遇好',
#  '包吃包住,年底多薪,晋升机会大',
#  '五险一金,大项目背景',
#  '餐贴,年终奖,体检,团建,下午茶点心,积极向上',
#  '平台大,氛围良好,机会多,奖金多多',
#  '周末双休,五险一金,技术氛围好,福利待遇佳',
#  '周末双休,节日福利,项目奖',
#  '福利,奖金,股权激励,双休,团建,体检,旅游',
#  '六险一金',
#  '国企控股,上市公司合资公司',
#  '做五休二,少加班',
#  '周末双休,年终奖金,五险一金,带薪年假',
#  '薪绩效奖,团队建设完善',
#  '薪,五险一金,双休,各类福利,稳定发展',
#  '大流量,福利好,发展空间大,团队氛围极好',
#  '团队年轻',
#  '五险一金,年终绩效,餐补',
#  '六险二金,通讯补贴,餐补,免费培训',
#  '五险一金,餐补',
#  '大牛带队成长快,全额五险一金,福利多',
#  '五险一金,带薪年假,奖金,福利补贴,股票期权',
#  '扁平化,下午茶,福利多,弹性,发展前景好',
#  '上市公司,互联网人工智能大厂',
#  '六险一金,周末双休,上市公司',
#  '上市公司,六险一金',
#  '周末双休,带薪年假,五险一金,年终奖',
#  '奖金福利,出国机会,高薪,办公',
#  '有挑战的事,上升空间大',
#  '年底奖金,期权',
#  '带薪年假,午餐补助,免费早餐,年度旅游',
#  '双休,带薪假,年假,晋升大,气氛融洽',
#  '六险一金,法定年假',
#  '领导,发展空间大',
#  '周末双休,健身下午茶,大牛云集,六险一金',
#  '大牛团队,行业领先',
#  '全额公积金,双休',
#  '五险一金,餐补',
#  '六险一金,周末双休,上市公司',
#  '平台',
#  '六险一金十四天带薪年假年终奖',
#  '高效团队,六险一金,股票期权',
#  '五险一金',
#  '上市公司,自有产品',
#  '在这里你将于技术牛人探讨最前沿的技术',
#  '五险一金,年度体检,智慧城市,管理规范',
#  '五险一金,大项目背景',
#  '工作生活平衡',
#  '平台大,氛围良好,机会多,奖金多多',
#  '周末双休',
#  '内部大型项目,微服务架构,工作稳定少加班',
#  '周末双休,五险一金,团队年轻,氛围好',
#  '福利待遇优厚',
#  '福利,奖金,股权激励,双休,团建,体检,旅游',
#  '行业发展前进好,大牛带队,团队氛围好',
#  '五险一金,餐费补贴,补充医疗保险',
#  '六险一金,商业保险,团队旅游,扁平化管理',
#  '五险一金,做五休二',
#  '周末双休,五险一金,外企环境',
#  '上市公司,多次调薪,五险一金,双休',
#  '基金公司,双休,加班少不补班',
#  '年终奖,六险一金,一档社保,带薪年假',
#  '大牛带队成长快,全额五险一金,福利多',
#  '福利待遇,发展前景',
#  '五险一金,餐补,定期体检,带薪年假,节日福利',
#  '未来可期',
#  '五险一金,周末双休,发展空间大',
#  '五险一金,带薪年假,奖金,福利补贴,股票期权',
#  '五险一金,子女保险',
#  '扁平化,下午茶,福利多,弹性,发展前景好',
#  '大平台,年终奖丰厚',
#  '发展前景好,晋升空间大,福利待遇优厚,弹性制',
#  '早期成员,施展空间大,工业软件,发展前景好',
#  '团队有爱,有热情,大牛如云',
#  '不加班',
#  '有挑战的事,上升空间大',
#  '阿里项目',
#  '国有企业交通餐补加班补助出差驻外补贴',
#  '国企背景,无常态化加班,免费班车,六险一金',
#  '双休,带薪假,年假,晋升大,气氛融洽',
#  '六险一金,福利好,大平台,大项目',
#  '上市公司,发展前景大,团队氛围好',
#  '创业型公司,自主研发,机会更大',
#  '大牛团队,弹性工作制,晋升制度',
#  '周末双休,五险一金,带薪年假',
#  '腾讯系团队,扁平管理,六险一金',
#  '上市公司,自有产品',
#  '技术能力提升,舒适的办公环境',
#  '福利待遇高,发展前景好',
#  '六险一金,商业保险,团队旅游,扁平化管理',
#  '平台大,氛围良好,机会多,奖金多多',
#  '免费三餐,团队氛围好',
#  '',
#  '国家高新技术企业,技术领先型公司',
#  '反馈快',
#  '大牛云集,福利补贴',
#  '大平台,福利好',
#  '福利,奖金,股权激励,双休,团建,体检,旅游',
#  '大型国企项目',
#  '季度绩效奖金',
#  '大平台,集团总部团队',
#  '升职空间大,弹性工作时间,以结果为导向',
#  '技术能力提升,舒适的办公环境',
#  '福利待遇高,发展前景好',
#  '银行项目',
#  '发展前景优,团队氛围好',
#  '成长快',
#  '国企正编,福利待遇好,平台资源大',
#  '高效团队,六险一金,股票期权',
#  '上市公司,平台大,福利好',
#  '天年假,医疗报销,旅游津贴',
#  '技术大牛,六险一金,周末双休,部门团建',
#  '免费住宿,上市背景,报销路费,薪酬高于市场',
#  '薪资待遇好',
#  '公司年轻有活力,团队氛围轻松',
#  '五险一金,带薪年假,节日福利,免费体检等',
#  '薪酬福利好,学习成长快',
#  '金融科技,头部券商,研发数字化转型',
#  '不内卷,周末双休,不加班',
#  '扁平化,下午茶,福利多,弹性,发展前景好',
#  '前景好,周末双休,五险一金',
#  '年终奖,项目奖,弹性办公,团建,年度旅游',
#  '扁平化管理',
#  '薪,五险一金,每年两次涨薪机会',
#  '上市公司,弹性工作,大牛带教',
#  '有挑战的事,上升空间大',
#  '弹性工作,五险一金,带薪培训,定期体检',
#  '年终奖,年,次调薪机会,带薪年假,补充医保',
#  '五险一金',
#  '六险一金,周末双休',
#  '期待你的加入',
#  '发展前景,团队氛围,薪酬福利',
#  '周末双休,零食下午茶',
#  '核心岗位,前景好,待遇好',
#  '上市公司,行业龙头,业务发展好,学金融投资',
#  '技术能力提升,舒适的办公环境',
#  '国资控股,六险一金,年度旅游,体检',
#  '技术新颖,团队氛围好',
#  '福利待遇高,发展前景好',
#  '发展前景优,团队氛围好',
#  '扁平化管理,领导,福利多',
#  '下午茶,小蛋糕,旅游,体检',
#  '平台大,福利完善,团队稳定,技术大牛',
#  '上市公司,自有产品',
#  '提供午餐,外企氛围',
#  '平台大,氛围良好,机会多,奖金多多',
#  '五险一金,周末双休,技术氛围好,发挥机会多',
#  '国家高新技术企业,技术领先型公司',
#  '双休,工作轻松稳定,有成长空间,五险一金',
#  '行业独角兽',
#  '工作气氛佳',
#  '股票期权,六险一金,弹性工作,硅谷培训',
#  '周末双休,加班补贴,扁平化,晋升渠道',
#  '项目稳定',
#  '上市金融科技龙头,福利好,学金融投资知识',
#  '团队年轻活力,行业领先者,发展前景好',
#  '发展潜力大,金融大数据龙头企业',
#  '团队年轻,五险一金,双休,下午茶,加班少',
#  '升职空间大,弹性工作时间,以结果为导向',
#  '五险一金,带薪年假,定期体检,节日福利',
#  '阿里控股,薪酬有竞争力,福利好,团队氛围轻松',
#  '一流的研发团队,广阔的发展空间',
#  '带薪年假,周末双休,节日福利',
#  ...]

# %%
# (\d+)人
staff = []
for i in data['inkDes']:
    staff.append(",".join(re.findall(re.compile(r'(\d+)人'),i)))

# %%
staff
# Out:
# ['2000',
#  '500',
#  '2000',
#  '150',
#  '2000',
#  '150',
#  '2000',
#  '2000',
#  '150',
#  '2000',
#  '150',
#  '2000',
#  '150',
#  '500',
#  '2000',
#  '150',
#  '50',
#  '50',
#  '2000',
#  '500',
#  '2000',
#  '15',
#  '150',
#  '500',
#  '50',
#  '50',
#  '150',
#  '50',
#  '2000',
#  '2000',
#  '2000',
#  '50',
#  '50',
#  '2000',
#  '2000',
#  '500',
#  '500',
#  '500',
#  '150',
#  '2000',
#  '50',
#  '2000',
#  '500',
#  '150',
#  '2000',
#  '500',
#  '2000',
#  '500',
#  '2000',
#  '500',
#  '150',
#  '150',
#  '500',
#  '500',
#  '500',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '500',
#  '2000',
#  '2000',
#  '150',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '500',
#  '500',
#  '2000',
#  '500',
#  '2000',
#  '150',
#  '2000',
#  '2000',
#  '2000',
#  '500',
#  '150',
#  '500',
#  '2000',
#  '2000',
#  '2000',
#  '50',
#  '50',
#  '2000',
#  '2000',
#  '2000',
#  '150',
#  '150',
#  '2000',
#  '150',
#  '500',
#  '500',
#  '150',
#  '2000',
#  '2000',
#  '15',
#  '2000',
#  '50',
#  '2000',
#  '150',
#  '2000',
#  '2000',
#  '150',
#  '150',
#  '2000',
#  '150',
#  '2000',
#  '150',
#  '150',
#  '150',
#  '2000',
#  '2000',
#  '500',
#  '500',
#  '500',
#  '500',
#  '2000',
#  '150',
#  '2000',
#  '50',
#  '2000',
#  '500',
#  '2000',
#  '500',
#  '2000',
#  '2000',
#  '500',
#  '2000',
#  '150',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '500',
#  '2000',
#  '2000',
#  '500',
#  '2000',
#  '2000',
#  '15',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '500',
#  '50',
#  '50',
#  '2000',
#  '2000',
#  '50',
#  '500',
#  '2000',
#  '500',
#  '2000',
#  '2000',
#  '150',
#  '150',
#  '2000',
#  '500',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '500',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '500',
#  '2000',
#  '500',
#  '500',
#  '150',
#  '500',
#  '2000',
#  '2000',
#  '500',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '500',
#  '500',
#  '2000',
#  '150',
#  '500',
#  '150',
#  '150',
#  '500',
#  '500',
#  '2000',
#  '500',
#  '2000',
#  '15',
#  '2000',
#  '150',
#  '2000',
#  '2000',
#  '2000',
#  '150',
#  '500',
#  '50',
#  '50',
#  '2000',
#  '150',
#  '500',
#  '2000',
#  '150',
#  '500',
#  '150',
#  '500',
#  '500',
#  '2000',
#  '2000',
#  '500',
#  '500',
#  '500',
#  '2000',
#  '150',
#  '500',
#  '2000',
#  '500',
#  '2000',
#  '500',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '15',
#  '2000',
#  '2000',
#  '50',
#  '500',
#  '150',
#  '2000',
#  '150',
#  '2000',
#  '500',
#  '2000',
#  '500',
#  '150',
#  '150',
#  '500',
#  '2000',
#  '500',
#  '2000',
#  '150',
#  '150',
#  '150',
#  '2000',
#  '150',
#  '2000',
#  '500',
#  '150',
#  '50',
#  '15',
#  '2000',
#  '50',
#  '2000',
#  '500',
#  '500',
#  '2000',
#  '2000',
#  '50',
#  '2000',
#  '500',
#  '150',
#  '2000',
#  '2000',
#  '500',
#  '2000',
#  '2000',
#  '150',
#  '150',
#  '150',
#  '2000',
#  '150',
#  '500',
#  '500',
#  '150',
#  '150',
#  '150',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '50',
#  '50',
#  '500',
#  '500',
#  '2000',
#  '150',
#  '500',
#  '150',
#  '2000',
#  '2000',
#  '500',
#  '2000',
#  '2000',
#  '500',
#  '2000',
#  '150',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '150',
#  '500',
#  '2000',
#  '150',
#  '500',
#  '2000',
#  '2000',
#  '2000',
#  '500',
#  '500',
#  '2000',
#  '150',
#  '2000',
#  '150',
#  '2000',
#  '2000',
#  '150',
#  '2000',
#  '150',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '500',
#  '500',
#  '500',
#  '500',
#  '150',
#  '500',
#  '2000',
#  '500',
#  '150',
#  '2000',
#  '15',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '500',
#  '500',
#  '2000',
#  '500',
#  '2000',
#  '2000',
#  '150',
#  '2000',
#  '2000',
#  '50',
#  '2000',
#  '2000',
#  '500',
#  '500',
#  '500',
#  '2000',
#  '500',
#  '2000',
#  '15',
#  '500',
#  '500',
#  '500',
#  '2000',
#  '500',
#  '500',
#  '2000',
#  '500',
#  '2000',
#  '2000',
#  '2000',
#  '50',
#  '2000',
#  '150',
#  '2000',
#  '2000',
#  '150',
#  '500',
#  '150',
#  '50',
#  '150',
#  '50',
#  '500',
#  '2000',
#  '2000',
#  '2000',
#  '150',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '500',
#  '150',
#  '2000',
#  '150',
#  '50',
#  '150',
#  '500',
#  '2000',
#  '150',
#  '2000',
#  '2000',
#  '50',
#  '2000',
#  '500',
#  '150',
#  '150',
#  '500',
#  '2000',
#  '150',
#  '2000',
#  '2000',
#  '50',
#  '2000',
#  '2000',
#  '500',
#  '2000',
#  '150',
#  '50',
#  '150',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '50',
#  '150',
#  '2000',
#  '500',
#  '150',
#  '2000',
#  '500',
#  '2000',
#  '50',
#  '500',
#  '500',
#  '150',
#  '50',
#  '2000',
#  '150',
#  '50',
#  '2000',
#  '2000',
#  '500',
#  '2000',
#  '500',
#  '2000',
#  '500',
#  '500',
#  '2000',
#  '500',
#  '500',
#  '2000',
#  '2000',
#  '500',
#  '2000',
#  '150',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '150',
#  '500',
#  '150',
#  '500',
#  '500',
#  '500',
#  '2000',
#  '150',
#  '2000',
#  '150',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '150',
#  '2000',
#  '150',
#  '2000',
#  '2000',
#  '500',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '500',
#  '500',
#  '2000',
#  '500',
#  '500',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '150',
#  '500',
#  '150',
#  '2000',
#  '150',
#  '150',
#  '50',
#  '150',
#  '150',
#  '150',
#  '50',
#  '50',
#  '2000',
#  '50',
#  '50',
#  '50',
#  '2000',
#  '15',
#  '150',
#  '150',
#  '2000',
#  '2000',
#  '500',
#  '2000',
#  '50',
#  '50',
#  '2000',
#  '15',
#  '2000',
#  '500',
#  '2000',
#  '150',
#  '50',
#  '2000',
#  '2000',
#  '500',
#  '150',
#  '50',
#  '500',
#  '15',
#  '500',
#  '500',
#  '15',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '150',
#  '500',
#  '2000',
#  '150',
#  '2000',
#  '150',
#  '2000',
#  '2000',
#  '150',
#  '2000',
#  '150',
#  '500',
#  '50',
#  '50',
#  '50',
#  '15',
#  '2000',
#  '2000',
#  '2000',
#  '500',
#  '50',
#  '2000',
#  '50',
#  '50',
#  '2000',
#  '2000',
#  '2000',
#  '150',
#  '50',
#  '150',
#  '50',
#  '150',
#  '150',
#  '150',
#  '2000',
#  '2000',
#  '2000',
#  '500',
#  '150',
#  '500',
#  '150',
#  '150',
#  '50',
#  '2000',
#  '150',
#  '150',
#  '50',
#  '2000',
#  '150',
#  '500',
#  '150',
#  '150',
#  '2000',
#  '500',
#  '50',
#  '150',
#  '2000',
#  '500',
#  '500',
#  '150',
#  '2000',
#  '2000',
#  '150',
#  '150',
#  '50',
#  '2000',
#  '50',
#  '500',
#  '2000',
#  '150',
#  '2000',
#  '2000',
#  '2000',
#  '15',
#  '50',
#  '150',
#  '2000',
#  '2000',
#  '2000',
#  '500',
#  '150',
#  '2000',
#  '50',
#  '150',
#  '2000',
#  '500',
#  '150',
#  '500',
#  '50',
#  '2000',
#  '2000',
#  '50',
#  '500',
#  '500',
#  '2000',
#  '2000',
#  '150',
#  '2000',
#  '2000',
#  '500',
#  '500',
#  '150',
#  '150',
#  '2000',
#  '2000',
#  '2000',
#  '500',
#  '2000',
#  '500',
#  '500',
#  '50',
#  '2000',
#  '2000',
#  '50',
#  '150',
#  '2000',
#  '2000',
#  '500',
#  '500',
#  '2000',
#  '500',
#  '2000',
#  '2000',
#  '2000',
#  '150',
#  '2000',
#  '2000',
#  '500',
#  '500',
#  '2000',
#  '500',
#  '2000',
#  '2000',
#  '2000',
#  '150',
#  '2000',
#  '500',
#  '2000',
#  '150',
#  '50',
#  '50',
#  '2000',
#  '2000',
#  '150',
#  '2000',
#  '500',
#  '500',
#  '50',
#  '150',
#  '150',
#  '500',
#  '2000',
#  '500',
#  '2000',
#  '150',
#  '2000',
#  '2000',
#  '2000',
#  '500',
#  '50',
#  '2000',
#  '150',
#  '500',
#  '500',
#  '150',
#  '500',
#  '50',
#  '150',
#  '500',
#  '2000',
#  '2000',
#  '500',
#  '50',
#  '150',
#  '500',
#  '500',
#  '2000',
#  '2000',
#  '50',
#  '50',
#  '500',
#  '500',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '500',
#  '500',
#  '2000',
#  '150',
#  '500',
#  '50',
#  '2000',
#  '150',
#  '500',
#  '150',
#  '500',
#  '150',
#  '50',
#  '150',
#  '500',
#  '2000',
#  '150',
#  '2000',
#  '500',
#  '2000',
#  '150',
#  '500',
#  '2000',
#  '2000',
#  '50',
#  '2000',
#  '2000',
#  '500',
#  '500',
#  '2000',
#  '150',
#  '2000',
#  '50',
#  '150',
#  '2000',
#  '2000',
#  '2000',
#  '500',
#  '2000',
#  '2000',
#  '50',
#  '500',
#  '500',
#  '2000',
#  '2000',
#  '2000',
#  '50',
#  '150',
#  '500',
#  '500',
#  '2000',
#  '150',
#  '2000',
#  '2000',
#  '2000',
#  '150',
#  '150',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '150',
#  '50',
#  '2000',
#  '150',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '500',
#  '500',
#  '500',
#  '150',
#  '500',
#  '150',
#  '2000',
#  '2000',
#  '2000',
#  '500',
#  '2000',
#  '50',
#  '2000',
#  '50',
#  '2000',
#  '150',
#  '500',
#  '2000',
#  '500',
#  '2000',
#  '2000',
#  '15',
#  '2000',
#  '2000',
#  '500',
#  '2000',
#  '500',
#  '2000',
#  '150',
#  '2000',
#  '2000',
#  '150',
#  '2000',
#  '500',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '150',
#  '2000',
#  '2000',
#  '500',
#  '50',
#  '2000',
#  '2000',
#  '2000',
#  '500',
#  '500',
#  '2000',
#  '2000',
#  '150',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '150',
#  '2000',
#  '2000',
#  '500',
#  '2000',
#  '150',
#  '50',
#  '2000',
#  '2000',
#  '2000',
#  '50',
#  '500',
#  '150',
#  '500',
#  '15',
#  '2000',
#  '2000',
#  '500',
#  '500',
#  '150',
#  '500',
#  '500',
#  '15',
#  '2000',
#  '150',
#  '50',
#  '2000',
#  '2000',
#  '50',
#  '2000',
#  '2000',
#  '2000',
#  '500',
#  '150',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '50',
#  '500',
#  '2000',
#  '500',
#  '2000',
#  '150',
#  '2000',
#  '2000',
#  '500',
#  '2000',
#  '50',
#  '150',
#  '500',
#  '500',
#  '150',
#  '50',
#  ...]

# %%
# (\w?[\u4e00-\u9fa5]+)
tmp = []
for i in data['inkDes']:
    tmp.append(",".join(re.findall(re.compile(r'(.*)\s\d+[-]?\d+人以?上?'),i)))
inkDes = []
for i in tmp:
    inkDes.append(",".join(re.findall(re.compile(r'(\w*[\u4e00-\u9fa5]+)'),i)))

# %%
inkDes
# Out:
# ['金融业,上市公司',
#  'IT技术服务,咨询,信息安全,不需要融资',
#  '软件服务,咨询,不需要融资',
#  '软件服务,咨询,不需要融资',
#  '科技金融,软件服务,咨询,不需要融资',
#  '数据服务,软件开发,不需要融资',
#  '科技金融,不需要融资',
#  'IT技术服务,咨询,上市公司',
#  '金融,数据服务,A轮',
#  '金融,D轮及以上',
#  '数据服务,咨询,人工智能服务,A轮',
#  'IT技术服务,咨询,上市公司',
#  '金融业,未融资',
#  '营销服务,咨询,不需要融资',
#  '软件服务,咨询,数据服务,咨询,信息安全,不需要融资',
#  'IT技术服务,咨询,天使轮',
#  '移动互联网,游戏,未融资',
#  '移动互联网,游戏,未融资',
#  '内容资讯,短视频,D轮及以上',
#  '智能硬件,未融资',
#  'IT技术服务,咨询,上市公司',
#  '',
#  'IT技术服务,咨询,不需要融资',
#  '汽车丨出行,物流丨运输,不需要融资',
#  'IT技术服务,咨询,营销服务,咨询,天使轮',
#  '软件服务,咨询,未融资',
#  'IT技术服务,咨询,未融资',
#  'IT技术服务,咨询,信息安全,软件服务,咨询,未融资',
#  '音频,视频媒体,上市公司',
#  'IT技术服务,咨询,上市公司',
#  'IT技术服务,咨询,上市公司',
#  '软件服务,咨询,未融资',
#  'IT技术服务,咨询,信息安全,软件服务,咨询,未融资',
#  '音频,视频媒体,上市公司',
#  'IT技术服务,咨询,上市公司',
#  '内容资讯,社交平台,B轮',
#  '人工智能服务,智能硬件,B轮',
#  '生活服务,软件服务,咨询,专业服务,咨询,未融资',
#  '软件服务,咨询,A轮',
#  '数据服务,咨询,人工智能服务,上市公司',
#  'IT技术服务,咨询,天使轮',
#  'IT技术服务,咨询,上市公司',
#  '硬件,不需要融资',
#  '金融业,不需要融资',
#  'IT技术服务,咨询,上市公司',
#  '硬件,不需要融资',
#  '软件服务,咨询,人工智能服务,上市公司',
#  '智能硬件,C轮',
#  '软件服务,咨询,上市公司',
#  '生活服务,软件服务,咨询,专业服务,咨询,未融资',
#  '电商,软件开发,不需要融资',
#  '软件服务,咨询,未融资',
#  '人工智能服务,智能硬件,B轮',
#  '电商平台,新零售,B轮',
#  '消费生活,电商,不需要融资',
#  'IT技术服务,咨询,软件服务,咨询,不需要融资',
#  'IT技术服务,咨询,上市公司',
#  'IT技术服务,咨询,上市公司',
#  '生活服务,上市公司',
#  '生活服务,软件服务,咨询,专业服务,咨询,未融资',
#  '金融,数据服务,上市公司',
#  '科技金融,不需要融资',
#  '金融业,不需要融资',
#  'IT技术服务,咨询,软件服务,咨询,未融资',
#  '软件服务,咨询,IT技术服务,咨询,上市公司',
#  '软件服务,咨询,IT技术服务,咨询,上市公司',
#  '软件服务,咨询,上市公司',
#  '人工智能服务,智能硬件,B轮',
#  '软件服务,咨询,IT技术服务,咨询,未融资',
#  '人工智能服务,软件服务,咨询,数据服务,咨询,上市公司',
#  '智能硬件,C轮',
#  'IT技术服务,咨询,不需要融资',
#  '软件服务,咨询,A轮',
#  '游戏,不需要融资',
#  '工具类产品,C轮',
#  '软件服务,咨询,上市公司',
#  '金融,数据服务,未融资',
#  '电商平台,IT技术服务,咨询,不需要融资',
#  '软件服务,咨询,IT技术服务,咨询,未融资',
#  'IT技术服务,咨询,未融资',
#  '人工智能服务,不需要融资',
#  '科技金融,不需要融资',
#  'IT技术服务,咨询,信息安全,软件服务,咨询,未融资',
#  'IT技术服务,咨询,天使轮',
#  'IT技术服务,咨询,上市公司',
#  'IT技术服务,咨询,上市公司',
#  '软件服务,咨询,上市公司',
#  '软件服务,咨询,不需要融资',
#  '科技金融,A轮',
#  'IT技术服务,咨询,上市公司',
#  '科技金融,A轮',
#  '电商平台,营销服务,咨询,制造业,未融资',
#  '软件服务,咨询,人工智能服务,A轮',
#  '区块链,C轮',
#  '科技金融,不需要融资',
#  '人工智能服务,IT技术服务,咨询,上市公司',
#  '',
#  'IT技术服务,咨询,软件服务,咨询,未融资',
#  '电商,文娱丨内容,A轮',
#  '金融业,上市公司',
#  'IT技术服务,咨询,不需要融资',
#  'IT技术服务,咨询,不需要融资',
#  'IT技术服务,咨询,上市公司',
#  'IT技术服务,咨询,软件服务,咨询,B轮',
#  '软件服务,咨询,A轮',
#  '软件服务,咨询,上市公司',
#  '文化传媒,休闲,娱乐,B轮',
#  '软件服务,咨询,数据服务,咨询,不需要融资',
#  'IT技术服务,咨询,未融资',
#  '科技金融,B轮',
#  '科技金融,B轮',
#  '企业服务,不需要融资',
#  'IT技术服务,咨询,不需要融资',
#  '软件服务,咨询,IT技术服务,咨询,不需要融资',
#  'IT技术服务,咨询,上市公司',
#  '电商平台,新零售,B轮',
#  '区块链,不需要融资',
#  'IT技术服务,咨询,软件服务,咨询,不需要融资',
#  '人工智能服务,不需要融资',
#  '软件服务,咨询,数据服务,咨询,物流平台,未融资',
#  '营销服务,咨询,专业服务,咨询,未融资',
#  '人工智能服务,软件服务,咨询,数据服务,咨询,上市公司',
#  '移动互联网,未融资',
#  'IT技术服务,咨询,软件服务,咨询,不需要融资',
#  '软件服务,咨询,数据服务,咨询,B轮',
#  '游戏,D轮及以上',
#  'IT技术服务,咨询,上市公司',
#  '硬件,C轮',
#  '科技金融,不需要融资',
#  '软件服务,咨询,不需要融资',
#  'IT技术服务,咨询,不需要融资',
#  '软件服务,咨询,C轮',
#  '科技金融,不需要融资',
#  'IT技术服务,咨询,上市公司',
#  '电商平台,上市公司',
#  '新零售,A轮',
#  '软件服务,咨询,数据服务,咨询,不需要融资',
#  '科技金融,不需要融资',
#  'IT技术服务,咨询,人工智能服务,D轮及以上',
#  '软件服务,咨询,上市公司',
#  'IT技术服务,咨询,软件服务,咨询,不需要融资',
#  '',
#  '人工智能服务,IT技术服务,咨询,上市公司',
#  '软件服务,咨询,C轮',
#  '科技金融,不需要融资',
#  '人工智能服务,IT技术服务,咨询,上市公司',
#  '软件服务,咨询,上市公司',
#  '科技金融,不需要融资',
#  '新零售,A轮',
#  '物联网,智能硬件,天使轮',
#  '企业服务,工具,物联网,不需要融资',
#  'IT技术服务,咨询,上市公司',
#  '软件服务,咨询,C轮',
#  '软件服务,咨询,人工智能服务,IT技术服务,咨询,未融资',
#  '社交平台,A轮',
#  '工具类产品,D轮及以上',
#  '金融业,未融资',
#  '人工智能服务,IT技术服务,咨询,上市公司',
#  'IT技术服务,咨询,软件服务,咨询,不需要融资',
#  '医疗,健康,不需要融资',
#  '文化传媒,休闲,娱乐,B轮',
#  '工具类产品,C轮',
#  'IT技术服务,咨询,上市公司',
#  'IT技术服务,咨询,软件服务,咨询,不需要融资',
#  '人工智能服务,不需要融资',
#  '软件服务,咨询,上市公司',
#  '物联网,上市公司',
#  '区块链,不需要融资',
#  '科技金融,不需要融资',
#  '科技金融,不需要融资',
#  '移动互联网,金融,不需要融资',
#  '软件服务,咨询,上市公司',
#  '物联网,网络通信,D轮及以上',
#  'IT技术服务,咨询,软件服务,咨询,不需要融资',
#  '移动互联网,未融资',
#  '金融业,未融资',
#  '科技金融,B轮',
#  '其他,不需要融资',
#  'IT技术服务,咨询,软件服务,咨询,不需要融资',
#  'IT技术服务,咨询,软件服务,咨询,不需要融资',
#  '软件服务,咨询,IT技术服务,咨询,不需要融资',
#  'IT技术服务,咨询,不需要融资',
#  'IT技术服务,咨询,上市公司',
#  '科技金融,不需要融资',
#  '科技金融,专业服务,咨询,房地产,建筑,物业,上市公司',
#  'IT技术服务,咨询,未融资',
#  '新零售,A轮',
#  '软件服务,咨询,数据服务,咨询,不需要融资',
#  '金融业,未融资',
#  '科技金融,B轮',
#  'IT技术服务,咨询,数据服务,咨询,A轮',
#  '其他,C轮',
#  'IT技术服务,咨询,网络通信,B轮',
#  '软件服务,咨询,未融资',
#  '软件服务,咨询,数据服务,咨询,C轮',
#  '人工智能服务,数据服务,咨询,不需要融资',
#  'IT技术服务,咨询,软件服务,咨询,不需要融资',
#  '',
#  '软件服务,咨询,上市公司',
#  '物联网,数据服务,咨询,A轮',
#  '软件服务,咨询,IT技术服务,咨询,上市公司',
#  '科技金融,不需要融资',
#  '移动互联网,金融,不需要融资',
#  '游戏,A轮',
#  'IT技术服务,咨询,C轮',
#  '科技金融,未融资',
#  '智能硬件,工具类产品,物联网,未融资',
#  'IT技术服务,咨询,软件服务,咨询,不需要融资',
#  '科技金融,B轮',
#  '软件服务,咨询,IT技术服务,咨询,不需要融资',
#  '软件服务,咨询,IT技术服务,咨询,上市公司',
#  '电商,未融资',
#  '科技金融,B轮',
#  '专业服务,咨询,未融资',
#  'IT技术服务,咨询,上市公司',
#  '软件服务,咨询,未融资',
#  '软件服务,咨询,上市公司',
#  '新零售,居住服务,上市公司',
#  '人工智能服务,软件服务,咨询,未融资',
#  '数据服务,咨询,A轮',
#  '营销服务,咨询,A轮',
#  'IT技术服务,咨询,上市公司',
#  '消费生活,专业服务,咨询,制造业,不需要融资',
#  '软件服务,咨询,未融资',
#  '科技金融,D轮及以上',
#  '人工智能服务,数据服务,咨询,不需要融资',
#  '科技金融,不需要融资',
#  '数据服务,咨询,不需要融资',
#  '硬件,上市公司',
#  'IT技术服务,咨询,软件服务,咨询,不需要融资',
#  'IT技术服务,咨询,软件服务,咨询,不需要融资',
#  '软件服务,咨询,上市公司',
#  '',
#  'IT技术服务,咨询,上市公司',
#  '制造业,上市公司',
#  '营销服务,咨询,专业服务,咨询,未融资',
#  '新零售,A轮',
#  '人工智能服务,未融资',
#  'IT技术服务,咨询,上市公司',
#  '金融业,未融资',
#  '软件服务,咨询,IT技术服务,咨询,上市公司',
#  '数据服务,咨询,不需要融资',
#  '软件服务,咨询,上市公司',
#  '人工智能服务,A轮',
#  '其他,C轮',
#  '软件服务,咨询,不需要融资',
#  'IT技术服务,咨询,网络通信,B轮',
#  '科技金融,上市公司',
#  '软件服务,咨询,未融资',
#  'IT技术服务,咨询,不需要融资',
#  '数据服务,软件开发,不需要融资',
#  '人工智能服务,不需要融资',
#  'IT技术服务,咨询,未融资',
#  '软件服务,咨询,数据服务,咨询,C轮',
#  '软件服务,咨询,IT技术服务,咨询,未融资',
#  '电商平台,内容社区,D轮及以上',
#  '人工智能服务,软件服务,咨询,B轮',
#  '软件服务,咨询,未融资',
#  '企业服务,电商,不需要融资',
#  '',
#  'IT技术服务,咨询,上市公司',
#  '科技金融,未融资',
#  '科技金融,专业服务,咨询,房地产,建筑,物业,上市公司',
#  '数据服务,咨询,A轮',
#  '电商平台,不需要融资',
#  '科技金融,未融资',
#  '内容资讯,短视频,D轮及以上',
#  '人工智能服务,区块链,A轮',
#  'IT技术服务,咨询,上市公司',
#  '人工智能服务,B轮',
#  '科技金融,B轮',
#  '数据服务,咨询,营销服务,咨询,C轮',
#  '科技金融,不需要融资',
#  '软件服务,咨询,IT技术服务,咨询,不需要融资',
#  '营销服务,咨询,数据服务,咨询,上市公司',
#  '营销服务,咨询,数据服务,咨询,上市公司',
#  '电商,未融资',
#  '人工智能服务,智能硬件,信息安全,未融资',
#  '文娱丨内容,天使轮',
#  '移动互联网,金融,不需要融资',
#  '游戏,A轮',
#  '人工智能服务,软件服务,咨询,不需要融资',
#  'IT技术服务,咨询,未融资',
#  '医疗丨健康,硬件,不需要融资',
#  '信息安全,B轮',
#  '广告营销,未融资',
#  'IT技术服务,咨询,上市公司',
#  '软件服务,咨询,上市公司',
#  '营销服务,咨询,数据服务,咨询,上市公司',
#  'IT技术服务,咨询,软件服务,咨询,不需要融资',
#  '制造业,上市公司',
#  '营销服务,咨询,专业服务,咨询,未融资',
#  '营销服务,咨询,专业服务,咨询,未融资',
#  '人工智能服务,数据服务,咨询,不需要融资',
#  '专业服务,咨询,未融资',
#  '软件服务,咨询,上市公司',
#  '医疗丨健康,硬件,不需要融资',
#  '软件服务,咨询,未融资',
#  '专业服务,咨询,未融资',
#  'IT技术服务,咨询,上市公司',
#  'IT技术服务,咨询,上市公司',
#  '软件服务,咨询,IT技术服务,咨询,不需要融资',
#  'IT技术服务,咨询,上市公司',
#  'IT技术服务,咨询,上市公司',
#  '软件服务,咨询,IT技术服务,咨询,不需要融资',
#  '软件服务,咨询,上市公司',
#  '科技金融,A轮',
#  'IT技术服务,咨询,不需要融资',
#  '物流,运输,A轮',
#  '科技金融,不需要融资',
#  '内容资讯,短视频,D轮及以上',
#  'IT技术服务,咨询,软件服务,咨询,不需要融资',
#  '人工智能服务,智能硬件,信息安全,未融资',
#  '软件服务,咨询,IT技术服务,咨询,未融资',
#  'IT技术服务,咨询,上市公司',
#  '电商,未融资',
#  '智能硬件,不需要融资',
#  '软件服务,咨询,IT技术服务,咨询,网络通信,不需要融资',
#  'IT技术服务,咨询,上市公司',
#  '物联网,不需要融资',
#  '数据服务,不需要融资',
#  '旅游,出行,B轮',
#  '制造业,上市公司',
#  '软件服务,咨询,A轮',
#  'IT技术服务,咨询,数据服务,咨询,不需要融资',
#  '软件服务,咨询,A轮',
#  '科技金融,不需要融资',
#  '软件服务,咨询,上市公司',
#  '移动互联网,教育,未融资',
#  'IT技术服务,咨询,不需要融资',
#  '科技金融,上市公司',
#  '软件服务,咨询,上市公司',
#  '软件服务,咨询,上市公司',
#  '游戏,D轮及以上',
#  '软件服务,咨询,数据服务,咨询,不需要融资',
#  'IT技术服务,咨询,上市公司',
#  'IT技术服务,咨询,上市公司',
#  'IT技术服务,咨询,上市公司',
#  'IT技术服务,咨询,上市公司',
#  '软件服务,咨询,人工智能服务,上市公司',
#  '软件服务,咨询,人工智能服务,上市公司',
#  '人工智能服务,软件服务,咨询,不需要融资',
#  '其他,不需要融资',
#  '数据服务,咨询,旅游,出行,A轮',
#  'IT技术服务,咨询,不需要融资',
#  '信息安全,B轮',
#  '区块链,不需要融资',
#  '软件服务,咨询,上市公司',
#  '消费生活,电商,不需要融资',
#  '其他,未融资',
#  'IT技术服务,咨询,上市公司',
#  '',
#  '科技金融,不需要融资',
#  'IT技术服务,咨询,上市公司',
#  'IT技术服务,咨询,上市公司',
#  'IT技术服务,咨询,上市公司',
#  'IT技术服务,咨询,上市公司',
#  '软件服务,咨询,上市公司',
#  'IT技术服务,咨询,软件服务,咨询,不需要融资',
#  '网络通信,上市公司',
#  '网络通信,未融资',
#  '内容资讯,信息检索,D轮及以上',
#  '科技金融,金融业,不需要融资',
#  '软件服务,咨询,上市公司',
#  '软件服务,咨询,IT技术服务,咨询,上市公司',
#  '软件服务,咨询,影视,动漫,A轮',
#  '软件服务,咨询,上市公司',
#  'IT技术服务,咨询,上市公司',
#  '数据服务,D轮及以上',
#  'IT技术服务,咨询,软件服务,咨询,上市公司',
#  '软件服务,咨询,人工智能服务,上市公司',
#  'IT技术服务,咨询,人工智能服务,D轮及以上',
#  '游戏,不需要融资',
#  '工具类产品,游戏,上市公司',
#  '内容资讯,短视频,D轮及以上',
#  '教育,培训,B轮',
#  'IT技术服务,咨询,软件服务,咨询,不需要融资',
#  '',
#  '教育,培训,B轮',
#  'IT技术服务,咨询,未融资',
#  '游戏,不需要融资',
#  'IT技术服务,咨询,软件服务,咨询,不需要融资',
#  '软件服务,咨询,新零售,天使轮',
#  '金融业,未融资',
#  '内容资讯,短视频,D轮及以上',
#  '软件服务,咨询,新零售,天使轮',
#  '专业服务,咨询,上市公司',
#  '科技金融,不需要融资',
#  '工具类产品,C轮',
#  '软件服务,咨询,A轮',
#  '软件服务,咨询,上市公司',
#  '科技金融,软件服务,咨询,内容社区,A轮',
#  '科技金融,不需要融资',
#  '内容资讯,短视频,D轮及以上',
#  '医疗,保健,美容,未融资',
#  '数据服务,天使轮',
#  '物联网,数据服务,咨询,A轮',
#  '消费生活,不需要融资',
#  'IT技术服务,咨询,人工智能服务,A轮',
#  '移动互联网,社交,天使轮',
#  '消费生活,电商,不需要融资',
#  '物联网,上市公司',
#  'IT技术服务,咨询,软件服务,咨询,上市公司',
#  '软件服务,咨询,IT技术服务,咨询,上市公司',
#  '在线教育,未融资',
#  '金融,数据服务,上市公司',
#  'IT技术服务,咨询,上市公司',
#  'IT技术服务,咨询,上市公司',
#  '内容资讯,短视频,D轮及以上',
#  'IT技术服务,咨询,上市公司',
#  '物联网,网络通信,D轮及以上',
#  '软件服务,咨询,不需要融资',
#  '金融业,不需要融资',
#  '区块链,IT技术服务,咨询,C轮',
#  '软件服务,咨询,人工智能服务,IT技术服务,咨询,未融资',
#  '移动互联网,不需要融资',
#  '其他,不需要融资',
#  'IT技术服务,咨询,软件服务,咨询,不需要融资',
#  '工具类产品,未融资',
#  'IT技术服务,咨询,上市公司',
#  'IT技术服务,咨询,上市公司',
#  '电商平台,数据服务,咨询,IT技术服务,咨询,不需要融资',
#  '软件服务,咨询,IT技术服务,咨询,网络通信,不需要融资',
#  '工具类产品,软件服务,咨询,人工智能服务,未融资',
#  '医疗,健康,不需要融资',
#  '软件服务,咨询,新零售,科技金融,未融资',
#  '金融业,未融资',
#  '软件服务,咨询,IT技术服务,咨询,网络通信,不需要融资',
#  'IT技术服务,咨询,未融资',
#  '电商平台,不需要融资',
#  '科技金融,不需要融资',
#  '数据服务,咨询,IT技术服务,咨询,未融资',
#  '人工智能服务,上市公司',
#  '智能硬件,不需要融资',
#  '人工智能服务,智能硬件,B轮',
#  '物联网,数据服务,咨询,软件服务,咨询,上市公司',
#  '医疗,保健,美容,C轮',
#  '游戏,IT技术服务,咨询,未融资',
#  '软件服务,咨询,上市公司',
#  '移动互联网,企业服务,不需要融资',
#  '生活服务,上市公司',
#  '电商平台,C轮',
#  'IT技术服务,咨询,数据服务,咨询,不需要融资',
#  '人工智能服务,IT技术服务,咨询,上市公司',
#  'IT技术服务,咨询,不需要融资',
#  '人工智能服务,A轮',
#  '服务业,上市公司',
#  'IT技术服务,咨询,上市公司',
#  '电商,上市公司',
#  '金融业,上市公司',
#  '软件服务,咨询,B轮',
#  '物流平台,C轮',
#  '软件服务,咨询,未融资',
#  '内容社区,C轮',
#  '广告营销,D轮及以上',
#  'IT技术服务,咨询,不需要融资',
#  '区块链,不需要融资',
#  '内容资讯,电商平台,消费生活,上市公司',
#  '电商平台,消费生活,不需要融资',
#  '医疗,保健,美容,在线医疗,不需要融资',
#  'IT技术服务,咨询,智能硬件,不需要融资',
#  '移动互联网,企业服务,不需要融资',
#  '软件开发,信息安全,D轮及以上',
#  '软件服务,咨询,上市公司',
#  '游戏,电商平台,不需要融资',
#  'IT技术服务,咨询,上市公司',
#  '影视,动漫,B轮',
#  '生活服务,软件服务,咨询,专业服务,咨询,未融资',
#  '工具类产品,软件服务,咨询,上市公司',
#  '电商平台,新零售,B轮',
#  '软件服务,咨询,不需要融资',
#  '内容资讯,短视频,D轮及以上',
#  'IT技术服务,咨询,上市公司',
#  '移动互联网,未融资',
#  '内容资讯,短视频,D轮及以上',
#  '电商平台,人工智能服务,智能硬件,A轮',
#  'IT技术服务,咨询,上市公司',
#  '内容资讯,短视频,D轮及以上',
#  '软件服务,咨询,IT技术服务,咨询,不需要融资',
#  'IT技术服务,咨询,专业服务,咨询,软件服务,咨询,未融资',
#  '软件服务,咨询,不需要融资',
#  '游戏,不需要融资',
#  '金融,移动互联网,不需要融资',
#  '社交平台,C轮',
#  '直播平台,A轮',
#  '软件服务,咨询,不需要融资',
#  '直播平台,未融资',
#  '软件服务,咨询,信息安全,网络通信,不需要融资',
#  '在线教育,D轮及以上',
#  '工具类产品,软件服务,咨询,IT技术服务,咨询,不需要融资',
#  '内容资讯,短视频,D轮及以上',
#  '内容资讯,短视频,D轮及以上',
#  '游戏,不需要融资',
#  '科技金融,不需要融资',
#  '移动互联网,不需要融资',
#  'IT技术服务,咨询,不需要融资',
#  '社交媒体,上市公司',
#  'IT技术服务,咨询,不需要融资',
#  '软件服务,咨询,上市公司',
#  '电商平台,上市公司',
#  '社交平台,D轮及以上',
#  '数据服务,咨询,上市公司',
#  '智能硬件,上市公司',
#  '教育,培训,上市公司',
#  '旅游,出行,上市公司',
#  '居住服务,上市公司',
#  'IT技术服务,咨询,上市公司',
#  '居住服务,上市公司',
#  '游戏,上市公司',
#  '科技金融,不需要融资',
#  '电商平台,上市公司',
#  '人工智能服务,数据服务,咨询,A轮',
#  '人工智能服务,数据服务,咨询,A轮',
#  '消费生活,上市公司',
#  '社交平台,D轮及以上',
#  'IT技术服务,咨询,B轮',
#  '物联网,不需要融资',
#  '软件服务,咨询,IT技术服务,咨询,不需要融资',
#  '信息检索,工具类产品,内容社区,上市公司',
#  '社交平台,社交媒体,不需要融资',
#  '软件服务,咨询,不需要融资',
#  'IT技术服务,咨询,未融资',
#  '科技金融,不需要融资',
#  '科技金融,上市公司',
#  '移动互联网,企业服务,未融资',
#  '移动互联网,企业服务,未融资',
#  '游戏,天使轮',
#  '专业服务,咨询,不需要融资',
#  '移动互联网,企业服务,未融资',
#  '移动互联网,企业服务,未融资',
#  'IT技术服务,咨询,不需要融资',
#  '物联网,不需要融资',
#  '教育,培训,IT技术服务,咨询,未融资',
#  '营销服务,咨询,生活服务,教育,培训,天使轮',
#  '营销服务,咨询,生活服务,教育,培训,天使轮',
#  '电商平台,软件服务,咨询,物流平台,不需要融资',
#  '营销服务,咨询,上市公司',
#  '',
#  '移动互联网,电商,不需要融资',
#  '电商,软件开发,不需要融资',
#  '电商平台,上市公司',
#  '科技金融,不需要融资',
#  '企业服务,上市公司',
#  '软件服务,咨询,上市公司',
#  '社交平台,短视频,社交媒体,不需要融资',
#  '企业服务,不需要融资',
#  '内容资讯,游戏,音频,视频媒体,上市公司',
#  '',
#  '内容资讯,信息检索,D轮及以上',
#  '移动互联网,A轮',
#  '内容资讯,社交媒体,不需要融资',
#  '游戏,天使轮',
#  '医疗丨健康,信息安全,不需要融资',
#  '内容资讯,短视频,D轮及以上',
#  '内容资讯,短视频,D轮及以上',
#  '社交平台,D轮及以上',
#  '移动互联网,企业服务,未融资',
#  '社交平台,短视频,社交媒体,不需要融资',
#  '居住服务,B轮',
#  '',
#  '人工智能,软件开发,未融资',
#  '专业服务,咨询,未融资',
#  '',
#  '数据服务,咨询,不需要融资',
#  '内容资讯,短视频,D轮及以上',
#  '内容资讯,短视频,D轮及以上',
#  '内容资讯,短视频,D轮及以上',
#  '内容资讯,短视频,D轮及以上',
#  '内容资讯,短视频,D轮及以上',
#  '内容资讯,短视频,D轮及以上',
#  '内容资讯,短视频,D轮及以上',
#  '内容资讯,短视频,D轮及以上',
#  '内容资讯,短视频,D轮及以上',
#  '内容资讯,短视频,D轮及以上',
#  '内容资讯,短视频,D轮及以上',
#  '内容资讯,短视频,D轮及以上',
#  '内容资讯,短视频,D轮及以上',
#  '内容资讯,短视频,D轮及以上',
#  '内容资讯,短视频,D轮及以上',
#  '内容资讯,短视频,D轮及以上',
#  '内容资讯,短视频,D轮及以上',
#  '内容资讯,短视频,D轮及以上',
#  '内容资讯,短视频,D轮及以上',
#  '内容资讯,短视频,D轮及以上',
#  '内容资讯,短视频,D轮及以上',
#  '内容资讯,短视频,D轮及以上',
#  '内容资讯,短视频,D轮及以上',
#  '内容资讯,短视频,D轮及以上',
#  '内容资讯,短视频,D轮及以上',
#  '内容资讯,短视频,D轮及以上',
#  '内容资讯,短视频,D轮及以上',
#  '内容资讯,短视频,D轮及以上',
#  '内容资讯,短视频,D轮及以上',
#  '内容资讯,短视频,D轮及以上',
#  '内容资讯,短视频,D轮及以上',
#  '内容资讯,短视频,D轮及以上',
#  '内容资讯,短视频,D轮及以上',
#  '内容资讯,短视频,D轮及以上',
#  '内容资讯,短视频,D轮及以上',
#  '内容资讯,短视频,D轮及以上',
#  '内容资讯,短视频,D轮及以上',
#  '内容资讯,短视频,D轮及以上',
#  '内容资讯,短视频,D轮及以上',
#  '内容资讯,短视频,D轮及以上',
#  '内容资讯,短视频,D轮及以上',
#  '内容资讯,短视频,D轮及以上',
#  '内容资讯,短视频,D轮及以上',
#  '内容资讯,短视频,D轮及以上',
#  '内容资讯,短视频,D轮及以上',
#  '内容资讯,短视频,D轮及以上',
#  '内容资讯,短视频,D轮及以上',
#  '内容资讯,短视频,D轮及以上',
#  '内容资讯,短视频,D轮及以上',
#  '内容资讯,短视频,D轮及以上',
#  '内容资讯,短视频,D轮及以上',
#  '内容资讯,短视频,D轮及以上',
#  '内容资讯,短视频,D轮及以上',
#  '内容资讯,短视频,D轮及以上',
#  '内容资讯,短视频,D轮及以上',
#  '内容资讯,短视频,D轮及以上',
#  '内容资讯,短视频,D轮及以上',
#  '内容资讯,短视频,D轮及以上',
#  '内容资讯,短视频,D轮及以上',
#  '内容资讯,短视频,D轮及以上',
#  '内容资讯,短视频,D轮及以上',
#  '内容资讯,短视频,D轮及以上',
#  '内容资讯,短视频,D轮及以上',
#  '内容资讯,短视频,D轮及以上',
#  '内容资讯,短视频,D轮及以上',
#  '内容资讯,短视频,D轮及以上',
#  '内容资讯,短视频,D轮及以上',
#  '科技金融,不需要融资',
#  '软件服务,咨询,IT技术服务,咨询,D轮及以上',
#  '智能硬件,上市公司',
#  '数据服务,咨询,人工智能服务,A轮',
#  'IT技术服务,咨询,上市公司',
#  '数据服务,咨询,人工智能服务,A轮',
#  '专业服务,咨询,不需要融资',
#  '电商,数据服务,上市公司',
#  '智能硬件,软件服务,咨询,A轮',
#  '电商,数据服务,上市公司',
#  '软件服务,咨询,不需要融资',
#  'IT技术服务,咨询,专业服务,咨询,物联网,不需要融资',
#  '工具类产品,不需要融资',
#  '移动互联网,不需要融资',
#  'IT技术服务,咨询,天使轮',
#  '',
#  'IT技术服务,咨询,软件服务,咨询,不需要融资',
#  '物流平台,A轮',
#  '物流平台,A轮',
#  'IT技术服务,咨询,C轮',
#  '软件服务,咨询,数据服务,咨询,不需要融资',
#  '软件服务,咨询,上市公司',
#  'IT技术服务,咨询,不需要融资',
#  '移动互联网,未融资',
#  '软件服务,咨询,IT技术服务,咨询,不需要融资',
#  '移动互联网,B轮',
#  '软件服务,咨询,上市公司',
#  '软件服务,咨询,未融资',
#  '移动互联网,A轮',
#  '软件开发,数据服务,未融资',
#  'IT技术服务,咨询,营销服务,咨询,天使轮',
#  'IT技术服务,咨询,软件服务,咨询,数据服务,咨询,未融资',
#  '数据服务,咨询,人工智能服务,A轮',
#  'IT技术服务,咨询,软件服务,咨询,数据服务,咨询,未融资',
#  'IT技术服务,咨询,上市公司',
#  '软件服务,咨询,上市公司',
#  '软件服务,咨询,上市公司',
#  '软件服务,咨询,IT技术服务,咨询,不需要融资',
#  '信息安全,不需要融资',
#  '软件服务,咨询,IT技术服务,咨询,不需要融资',
#  '工具,未融资',
#  '工具类产品,未融资',
#  '科技金融,未融资',
#  '软件服务,咨询,上市公司',
#  'IT技术服务,咨询,不需要融资',
#  'IT技术服务,咨询,上市公司',
#  '软件服务,咨询,工具类产品,不需要融资',
#  '工具类产品,内容资讯,上市公司',
#  '数据服务,咨询,人工智能服务,A轮',
#  '软件服务,咨询,IT技术服务,咨询,不需要融资',
#  '数据服务,咨询,人工智能服务,A轮',
#  '医疗丨健康,硬件,不需要融资',
#  'IT技术服务,咨询,上市公司',
#  '软件服务,咨询,IT技术服务,咨询,不需要融资',
#  'IT技术服务,咨询,营销服务,咨询,天使轮',
#  'IT技术服务,咨询,软件服务,咨询,数据服务,咨询,未融资',
#  '软件服务,咨询,上市公司',
#  '数据服务,咨询,旅游,出行,A轮',
#  'IT技术服务,咨询,信息安全,B轮',
#  'IT技术服务,咨询,数据服务,咨询,A轮',
#  '其他,不需要融资',
#  'IT技术服务,咨询,上市公司',
#  'IT技术服务,咨询,上市公司',
#  '游戏,A轮',
#  '软件服务,咨询,电商平台,不需要融资',
#  '软件服务,咨询,上市公司',
#  '科技金融,不需要融资',
#  '营销服务,咨询,不需要融资',
#  'IT技术服务,咨询,上市公司',
#  '直播平台,不需要融资',
#  'IT技术服务,咨询,上市公司',
#  '软件服务,咨询,IT技术服务,咨询,上市公司',
#  '数据服务,区块链,不需要融资',
#  '',
#  '营销服务,咨询,人工智能服务,未融资',
#  '电商,软件开发,不需要融资',
#  '金融,数据服务,上市公司',
#  '物联网,上市公司',
#  'IT技术服务,咨询,上市公司',
#  'IT技术服务,咨询,C轮',
#  '移动互联网,B轮',
#  'IT技术服务,咨询,上市公司',
#  'IT技术服务,咨询,营销服务,咨询,天使轮',
#  'IT技术服务,咨询,软件服务,咨询,数据服务,咨询,未融资',
#  '软件服务,咨询,上市公司',
#  '数据服务,咨询,旅游,出行,A轮',
#  '数据服务,咨询,C轮',
#  '在线教育,A轮',
#  'IT技术服务,咨询,软件服务,咨询,不需要融资',
#  'IT技术服务,咨询,上市公司',
#  '物联网,不需要融资',
#  '软件服务,咨询,人工智能服务,A轮',
#  'IT技术服务,咨询,网络通信,B轮',
#  'IT技术服务,咨询,B轮',
#  'IT技术服务,咨询,不需要融资',
#  '其他,不需要融资',
#  'IT技术服务,咨询,不需要融资',
#  'IT技术服务,咨询,软件服务,咨询,上市公司',
#  '工具类产品,上市公司',
#  '软件服务,咨询,IT技术服务,咨询,不需要融资',
#  '消费生活,电商,不需要融资',
#  'IT技术服务,咨询,上市公司',
#  '软件服务,咨询,A轮',
#  '软件服务,咨询,上市公司',
#  'IT技术服务,咨询,上市公司',
#  'IT技术服务,咨询,上市公司',
#  '软件服务,咨询,上市公司',
#  '专业服务,咨询,上市公司',
#  '人工智能,上市公司',
#  '直播平台,未融资',
#  '信息安全,医疗丨健康,未融资',
#  '金融,数据服务,上市公司',
#  '在线教育,内容资讯,不需要融资',
#  'IT技术服务,咨询,营销服务,咨询,天使轮',
#  'IT技术服务,咨询,软件服务,咨询,数据服务,咨询,未融资',
#  'IT技术服务,咨询,不需要融资',
#  '软件服务,咨询,上市公司',
#  '科技金融,IT技术服务,咨询,不需要融资',
#  '消费生活,电商,不需要融资',
#  'IT技术服务,咨询,上市公司',
#  '软件服务,咨询,IT技术服务,咨询,不需要融资',
#  'IT技术服务,咨询,上市公司',
#  '新媒体,不需要融资',
#  '旅游,出行,D轮及以上',
#  '数据服务,咨询,新零售,农林牧渔,不需要融资',
#  'IT技术服务,咨询,上市公司',
#  '工具类产品,上市公司',
#  'IT技术服务,咨询,B轮',
#  '新能源汽车制造,未融资',
#  '软件服务,咨询,上市公司',
#  'IT技术服务,咨询,未融资',
#  '其他,不需要融资',
#  'IT技术服务,咨询,上市公司',
#  'IT技术服务,咨询,上市公司',
#  '移动互联网,数据服务,上市公司',
#  '软件服务,咨询,上市公司',
#  'IT技术服务,咨询,B轮',
#  '软件服务,咨询,上市公司',
#  'IT技术服务,咨询,区块链,不需要融资',
#  'IT技术服务,咨询,天使轮',
#  '移动互联网,数据服务,未融资',
#  'IT技术服务,咨询,上市公司',
#  '工具类产品,上市公司',
#  '休闲,娱乐,A轮',
#  '金融,数据服务,上市公司',
#  '软件服务,咨询,IT技术服务,咨询,不需要融资',
#  'IT技术服务,咨询,未融资',
#  'IT技术服务,咨询,营销服务,咨询,天使轮',
#  'IT技术服务,咨询,软件服务,咨询,数据服务,咨询,未融资',
#  '物联网,上市公司',
#  'IT技术服务,咨询,B轮',
#  '工具类产品,软件服务,咨询,上市公司',
#  'IT技术服务,咨询,未融资',
#  '其他,不需要融资',
#  '移动互联网,数据服务,上市公司',
#  '软件服务,咨询,IT技术服务,咨询,不需要融资',
#  'IT技术服务,咨询,软件服务,咨询,不需要融资',
#  '居住服务,上市公司',
#  'IT技术服务,咨询,B轮',
#  '移动互联网,数据服务,未融资',
#  '文娱丨内容,旅游,上市公司',
#  '软件服务,咨询,数据服务,咨询,人工智能服务,A轮',
#  '数据服务,咨询,上市公司',
#  'IT技术服务,咨询,B轮',
#  'IT技术服务,咨询,软件服务,咨询,数据服务,咨询,未融资',
#  '人工智能服务,C轮',
#  '软件服务,咨询,数据服务,咨询,人工智能服务,未融资',
#  '社交媒体,内容社区,短视频,不需要融资',
#  '新零售,工具类产品,不需要融资',
#  '移动互联网,B轮',
#  'IT技术服务,咨询,上市公司',
#  'IT技术服务,咨询,不需要融资',
#  '移动互联网,不需要融资',
#  '在线教育,天使轮',
#  'IT技术服务,咨询,未融资',
#  '数据服务,咨询,A轮',
#  '电商平台,上市公司',
#  '软件服务,咨询,IT技术服务,咨询,不需要融资',
#  '专业服务,咨询,IT技术服务,咨询,不需要融资',
#  'IT技术服务,咨询,未融资',
#  '新零售,工具类产品,不需要融资',
#  'IT技术服务,咨询,B轮',
#  '软件服务,咨询,C轮',
#  'IT技术服务,咨询,上市公司',
#  '软件服务,咨询,上市公司',
#  '在线教育,A轮',
#  '人工智能服务,不需要融资',
#  '软件服务,咨询,人工智能服务,区块链,不需要融资',
#  '金融业,上市公司',
#  '游戏,内容社区,B轮',
#  '科技金融,C轮',
#  '企业服务,A轮',
#  '游戏,不需要融资',
#  '人工智能服务,B轮',
#  'IT技术服务,咨询,B轮',
#  'IT技术服务,咨询,软件服务,咨询,数据服务,咨询,未融资',
#  '人工智能服务,C轮',
#  'IT技术服务,咨询,未融资',
#  '软件服务,咨询,数据服务,咨询,人工智能服务,未融资',
#  '科技金融,不需要融资',
#  '新零售,工具类产品,不需要融资',
#  '在线医疗,医疗,保健,美容,不需要融资',
#  '电商平台,未融资',
#  '移动互联网,B轮',
#  'IT技术服务,咨询,不需要融资',
#  '科技金融,未融资',
#  '在线教育,天使轮',
#  'IT技术服务,咨询,未融资',
#  '移动互联网,其他,D轮及以上',
#  'IT技术服务,咨询,上市公司',
#  '企业服务,A轮',
#  '软件服务,咨询,IT技术服务,咨询,不需要融资',
#  '在线医疗,医疗,保健,美容,不需要融资',
#  '网络通信,不需要融资',
#  'IT技术服务,咨询,B轮',
#  'IT技术服务,咨询,不需要融资',
#  '软件服务,咨询,未融资',
#  '物流,运输,上市公司',
#  '软件开发,未融资',
#  '人工智能服务,IT技术服务,咨询,未融资',
#  '硬件,数据服务,不需要融资',
#  '游戏,不需要融资',
#  '科技金融,不需要融资',
#  '科技金融,C轮',
#  '金融业,上市公司',
#  'IT技术服务,咨询,上市公司',
#  '人工智能服务,A轮',
#  'IT技术服务,咨询,B轮',
#  '人工智能服务,C轮',
#  'IT技术服务,咨询,不需要融资',
#  'IT技术服务,咨询,不需要融资',
#  '软件服务,咨询,上市公司',
#  '软件服务,咨询,数据服务,咨询,人工智能服务,未融资',
#  '科技金融,不需要融资',
#  '新零售,工具类产品,不需要融资',
#  'IT技术服务,咨询,B轮',
#  '游戏,不需要融资',
#  '在线教育,天使轮',
#  'IT技术服务,咨询,未融资',
#  '软件服务,咨询,人工智能服务,不需要融资',
#  '游戏,直播平台,B轮',
#  'IT技术服务,咨询,科技金融,人工智能服务,不需要融资',
#  '科技金融,人工智能服务,A轮',
#  'IT技术服务,咨询,上市公司',
#  'IT技术服务,咨询,不需要融资',
#  'IT技术服务,咨询,不需要融资',
#  '软件服务,咨询,上市公司',
#  'IT技术服务,咨询,人工智能服务,天使轮',
#  'IT技术服务,咨询,软件服务,咨询,数据服务,咨询,未融资',
#  'IT技术服务,咨询,上市公司',
#  '软件服务,咨询,A轮',
#  '软件服务,咨询,IT技术服务,咨询,上市公司',
#  'IT技术服务,咨询,上市公司',
#  '数据服务,咨询,不需要融资',
#  '软件服务,咨询,IT技术服务,咨询,不需要融资',
#  'IT技术服务,咨询,上市公司',
#  '专业服务,咨询,不需要融资',
#  'IT技术服务,咨询,物联网,不需要融资',
#  '企业服务,教育,未融资',
#  'IT技术服务,咨询,B轮',
#  '移动互联网,教育,未融资',
#  '在线医疗,不需要融资',
#  '智能硬件,未融资',
#  '人工智能服务,上市公司',
#  '软件服务,咨询,上市公司',
#  '金融,数据服务,上市公司',
#  '数据服务,不需要融资',
#  '软件服务,咨询,上市公司',
#  '人工智能服务,A轮',
#  '软件服务,咨询,IT技术服务,咨询,上市公司',
#  '企业服务,数据服务,未融资',
#  '科技金融,D轮及以上',
#  '能源,矿产,环保,A轮',
#  'IT技术服务,咨询,B轮',
#  '科技金融,金融业,C轮',
#  '人工智能服务,C轮',
#  '数据服务,咨询,不需要融资',
#  '金融业,上市公司',
#  '',
#  '电商平台,上市公司',
#  'IT技术服务,咨询,上市公司',
#  '新零售,工具类产品,不需要融资',
#  '人工智能服务,软件服务,咨询,数据服务,咨询,上市公司',
#  '软件服务,咨询,物联网,不需要融资',
#  'IT技术服务,咨询,信息安全,软件服务,咨询,不需要融资',
#  '在线教育,天使轮',
#  '软件服务,咨询,IT技术服务,咨询,不需要融资',
#  '数据服务,咨询,营销服务,咨询,上市公司',
#  '工具类产品,不需要融资',
#  '人工智能服务,数据服务,咨询,C轮',
#  '数据服务,咨询,C轮',
#  '科技金融,上市公司',
#  'IT技术服务,咨询,上市公司',
#  'IT技术服务,咨询,不需要融资',
#  '软件服务,咨询,上市公司',
#  '智能硬件,未融资',
#  '软件服务,咨询,IT技术服务,咨询,不需要融资',
#  '电商平台,内容社区,D轮及以上',
#  '人工智能服务,IT技术服务,咨询,B轮',
#  'IT技术服务,咨询,未融资',
#  'IT技术服务,咨询,未融资',
#  'IT技术服务,咨询,不需要融资',
#  '社交媒体,上市公司',
#  'IT技术服务,咨询,B轮',
#  'IT技术服务,咨询,未融资',
#  '科技金融,不需要融资',
#  '软件服务,咨询,上市公司',
#  '文娱丨内容,广告营销,A轮',
#  'IT技术服务,咨询,不需要融资',
#  '软件服务,咨询,上市公司',
#  'IT技术服务,咨询,上市公司',
#  '企业服务,工具,通讯电子,不需要融资',
#  '物联网,不需要融资',
#  '网络通信,不需要融资',
#  'IT技术服务,咨询,人工智能服务,天使轮',
#  '居住服务,上市公司',
#  'IT技术服务,咨询,上市公司',
#  '软件服务,咨询,数据服务,咨询,B轮',
#  '金融,数据服务,上市公司',
#  '生活服务,天使轮',
#  '批发,零售,贸易,进出口,天使轮',
#  '生活服务,B轮',
#  '新零售,电商平台,上市公司',
#  '金融业,上市公司',
#  '移动互联网,不需要融资',
#  '人工智能服务,C轮',
#  '软件服务,咨询,数据服务,咨询,智能硬件,不需要融资',
#  '软件服务,咨询,未融资',
#  '',
#  '金融,数据服务,上市公司',
#  '物流,运输,上市公司',
#  '新零售,工具类产品,不需要融资',
#  '企业服务,工具,金融,不需要融资',
#  'IT技术服务,咨询,不需要融资',
#  '消费生活,电商,不需要融资',
#  '软件服务,咨询,IT技术服务,咨询,不需要融资',
#  '',
#  '物流平台,A轮',
#  '直播平台,未融资',
#  '贸易,进出口,软件服务,咨询,电商平台,天使轮',
#  '科技金融,上市公司',
#  'IT技术服务,咨询,不需要融资',
#  '软件服务,咨询,数据服务,咨询,IT技术服务,咨询,天使轮',
#  '科技金融,不需要融资',
#  '软件服务,咨询,上市公司',
#  '企业服务,工具,通讯电子,不需要融资',
#  '人工智能服务,不需要融资',
#  '信息安全,天使轮',
#  '智能硬件,不需要融资',
#  'IT技术服务,咨询,上市公司',
#  '软件服务,咨询,上市公司',
#  '软件服务,咨询,IT技术服务,咨询,不需要融资',
#  '数据服务,咨询,上市公司',
#  'IT技术服务,咨询,未融资',
#  'IT技术服务,咨询,网络通信,B轮',
#  '旅游,出行,D轮及以上',
#  '数据服务,咨询,人工智能服务,物联网,未融资',
#  '软件服务,咨询,IT技术服务,咨询,上市公司',
#  '科技金融,A轮',
#  '软件服务,咨询,上市公司',
#  '科技金融,上市公司',
#  '企业服务,教育,未融资',
#  '数据服务,咨询,不需要融资',
#  '电商,文娱丨内容,A轮',
#  '文娱丨内容,广告营销,A轮',
#  '人工智能服务,A轮',
#  '新零售,工具类产品,不需要融资',
#  '其他,未融资',
#  'IT技术服务,咨询,软件服务,咨询,不需要融资',
#  ...]

# %%
low_wages = pd.DataFrame(low_wages, columns=['low_wages'])
hight_wages = pd.DataFrame(hight_wages, columns=['hight_wages'])
year_wages = pd.DataFrame(year_wages, columns=['year_wages'])
city = pd.DataFrame(city, columns=['city'])
skill = pd.DataFrame(skill, columns=['skill'])
jobDes = pd.DataFrame(jobDes, columns=['jobDes'])
staff = pd.DataFrame(staff, columns=['staff'])
inkDes = pd.DataFrame(inkDes, columns=['inkDes'])

# data2 = pd.concat([data['job'], low_wages, hight_wages, year_wages, city,
#                   data['ink'], staff, skill, jobDes, inkDes], axis=1)

# %%
data2 = pd.concat([data['tag'], data['job'], low_wages, hight_wages, year_wages, city,
                  data['ink'], staff, skill, jobDes, inkDes], axis=1)

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2692 entries, 0 to 2691
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   tag          2692 non-null   int64
#  1   job          2692 non-null   object
#  2   low_wages    2692 non-null   float64
#  3   hight_wages  2692 non-null   float64
#  4   year_wages   2692 non-null   float64
#  5   city         2692 non-null   object
#  6   ink          2692 non-null   object
#  7   staff        2692 non-null   object
#  8   skill        2692 non-null   object
#  9   jobDes       2692 non-null   object
#  10  inkDes       2692 non-null   object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 231.5+ KB

# %%
data3 = data2.replace('',np.nan)
data3 = data2.dropna()

# %%
data3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2692 entries, 0 to 2691
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   tag          2692 non-null   int64
#  1   job          2692 non-null   object
#  2   low_wages    2692 non-null   float64
#  3   hight_wages  2692 non-null   float64
#  4   year_wages   2692 non-null   float64
#  5   city         2692 non-null   object
#  6   ink          2692 non-null   object
#  7   staff        2692 non-null   object
#  8   skill        2692 non-null   object
#  9   jobDes       2692 non-null   object
#  10  inkDes       2692 non-null   object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 231.5+ KB

# %%
data2.to_csv("data/预处理完成数据.csv", encoding='utf_8_sig')
